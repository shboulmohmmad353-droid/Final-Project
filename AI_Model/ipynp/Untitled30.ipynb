# %%
import subprocess
subprocess.run(['pip', 'install', '-q', 'albumentations'], check=False)

# 1. IMPORTS
import os, json, zipfile, random, warnings, glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from tqdm import tqdm
warnings.filterwarnings('ignore')

import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, regularizers        # ← أضفنا regularizers
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB3, EfficientNetB4, ResNet50V2, DenseNet121
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import seaborn as sns
import albumentations as A

print(f" TensorFlow : {tf.__version__}")
print(f" GPU        : {tf.config.list_physical_devices('GPU')}")

# 2. CONFIGURATION
IMG_SIZE   = (224,224)
BATCH_SIZE = 16
EPOCHS     = 30
SEED       = 42
LR_PHASE1  = 1e-3
LR_PHASE2  = 5e-5
L2_REG        = 1e-4                                            # ← قيمة L2
CLS_THRESHOLD = 0.65                                            # ← رفع threshold لتحسين Precision

# 'DenseNet121'
MODEL_CHOICE = 'DenseNet121'

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

IMG_H, IMG_W = IMG_SIZE

tf.keras.mixed_precision.set_global_policy('mixed_float16')
print(f" Mixed Precision: {tf.keras.mixed_precision.global_policy().name}")
print(f" Model Choice   : {MODEL_CHOICE}")
print(f" L2 Regularization: {L2_REG}")
print(f" CLS Threshold    : {CLS_THRESHOLD}")                  # ← طباعة الـ threshold

def find_zip_file():
    candidates = [
        '/content/archive__32_.zip',
        '/content/drive/MyDrive/archive__32_.zip',
        '/content/drive/My Drive/archive__32_.zip',
    ]
    drive_search = glob.glob('/content/drive/**/*archive*32*.zip', recursive=True)
    drive_search += glob.glob('/content/drive/**/*.zip', recursive=True)
    candidates += drive_search

    for path in candidates:
        if os.path.exists(path):
            print(f"I found the file ZIP: {path}")
            return path
    return None

try:
    from google.colab import drive
    if not os.path.exists('/content/drive'):
        print("Installation in progress Google Drive...")
        drive.mount('/content/drive')
    else:
        print(" Google Drive Pre-assembled")
except Exception as e:
    print(f"  Drive Not available: {e}")

ZIP_PATH = find_zip_file()

if ZIP_PATH is None:
    print("\n  The file was not found automatically.")
    print("Upload the file now (archive__32_.zip)...")
    try:
        from google.colab import files
        uploaded = files.upload()
        for fname in uploaded:
            dest = f'/content/{fname}'
            with open(dest, 'wb') as f:
                f.write(uploaded[fname])
            ZIP_PATH = dest
            print(f"Uploaded: {dest}")
            break
    except Exception as e:
        raise FileNotFoundError(
            f" The file was not found.\n"
            f"Solution: Manually upload the file to /content/ and press Run again. \n{e}"
        )

print(f"\npath ZIP: {ZIP_PATH}")


# 4. EXTRACT ZIP
print("\n Extracting dataset...")

EXTRACT_ROOT = '/content/extracted_dataset'
os.makedirs(EXTRACT_ROOT, exist_ok=True)

with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_ROOT)

print(" Extraction complete")

DATASET_DIR = None
for root, dirs, _ in os.walk(EXTRACT_ROOT):
    if 'FracAtlas' in dirs:
        DATASET_DIR = os.path.join(root, 'FracAtlas')
        break
    if os.path.basename(root) == 'FracAtlas':
        DATASET_DIR = root
        break

if DATASET_DIR is None:
    for root, dirs, _ in os.walk(EXTRACT_ROOT):
        if 'images' in dirs:
            DATASET_DIR = root
            break

if DATASET_DIR is None:
    raise FileNotFoundError(f"The FracAtlas folder was not found inside theZIP.\n"
                             f"Extracted volumes: {os.listdir(EXTRACT_ROOT)}")

print(f" Dataset path: {DATASET_DIR}")

FRAC_DIR    = os.path.join(DATASET_DIR, 'images', 'Fractured')
NONFRAC_DIR = os.path.join(DATASET_DIR, 'images', 'Non_fractured')
COCO_PATH   = os.path.join(DATASET_DIR, 'Annotations', 'COCO JSON', 'COCO_fracture_masks.json')

for p in [FRAC_DIR, NONFRAC_DIR, COCO_PATH]:
    if not os.path.exists(p):
        raise FileNotFoundError(f" Lost Path: {p}")
print(" All dataset paths verified")

# 5. NORMALIZE EXTENSIONS & IMAGE SIZES
def normalize_images(folder, target_ext='.jpg', target_size=IMG_SIZE):
    converted = 0
    for fname in os.listdir(folder):
        fpath = os.path.join(folder, fname)
        ext = os.path.splitext(fname)[1].lower()
        if ext not in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp']:
            continue
        try:
            img = Image.open(fpath).convert('RGB')
            if ext != target_ext:
                new_path = os.path.splitext(fpath)[0] + target_ext
                img.save(new_path, 'JPEG', quality=95)
                os.remove(fpath)
                converted += 1
        except Exception as e:
            print(f"  Skipping {fname}: {e}")
    print(f"  Converted {converted} files in {os.path.basename(folder)}")

print("\n Normalizing image extensions...")
normalize_images(FRAC_DIR)
normalize_images(NONFRAC_DIR)

# 6. LOAD COCO ANNOTATIONS
with open(COCO_PATH, 'r') as f:
    coco_data = json.load(f)

id_to_img     = {img['id']: img for img in coco_data['images']}
fname_to_anns = {}
for ann in coco_data['annotations']:
    img_info = id_to_img[ann['image_id']]
    fname    = img_info['file_name']
    if fname not in fname_to_anns:
        fname_to_anns[fname] = []
    fname_to_anns[fname].append({
        'bbox'        : ann['bbox'],
        'segmentation': ann['segmentation'],
        'orig_w'      : img_info['width'],
        'orig_h'      : img_info['height'],
    })

print(f"\n Loaded {len(coco_data['annotations'])} annotations "
      f"for {len(fname_to_anns)} fractured images")

# 7. DATA EXPLORATION & VISUALIZATION
VALID_EXTS    = ('.jpg', '.jpeg', '.png')
frac_files    = [f for f in os.listdir(FRAC_DIR)    if f.lower().endswith(VALID_EXTS)]
nonfrac_files = [f for f in os.listdir(NONFRAC_DIR) if f.lower().endswith(VALID_EXTS)]

n_frac    = len(frac_files)
n_nonfrac = len(nonfrac_files)
total     = n_frac + n_nonfrac

print(f"\n{'='*50}")
print(f"  Fractured    : {n_frac:>5}  ({100*n_frac/total:.1f}%)")
print(f"  Non-Fractured: {n_nonfrac:>5}  ({100*n_nonfrac/total:.1f}%)")
print(f"  Total        : {total:>5}")
print(f"  Imbalance    : 1:{n_nonfrac//max(n_frac,1)}")
print(f"{'='*50}")

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle(' FracAtlas — Dataset Analysis', fontsize=16, fontweight='bold', y=0.98)

# Bar chart
ax = axes[0, 0]
bars = ax.bar(['Fractured', 'Non-Fractured'], [n_frac, n_nonfrac],
              color=['#E74C3C', '#2ECC71'], edgecolor='white', linewidth=1.5, width=0.5)
for bar, val in zip(bars, [n_frac, n_nonfrac]):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 40,
            f'{val}\n({100*val/total:.1f}%)', ha='center', fontweight='bold', fontsize=11)
ax.set_title('Class Distribution', fontweight='bold')
ax.set_ylabel('Number of Images')
ax.set_ylim(0, max(n_frac, n_nonfrac) * 1.25)
ax.spines[['top', 'right']].set_visible(False)

# Pie chart
ax = axes[0, 1]
_, _, autotexts = ax.pie(
    [n_frac, n_nonfrac],
    labels=['Fractured', 'Non-Fractured'],
    autopct='%1.1f%%',
    colors=['#E74C3C', '#2ECC71'],
    startangle=140,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
for at in autotexts:
    at.set_fontweight('bold')
ax.set_title('Class Ratio', fontweight='bold')

# Image width distribution
ax = axes[0, 2]
widths = []
for f in random.sample(frac_files,    min(50, len(frac_files))):
    try: widths.append(Image.open(os.path.join(FRAC_DIR, f)).size[0])
    except: pass
for f in random.sample(nonfrac_files, min(50, len(nonfrac_files))):
    try: widths.append(Image.open(os.path.join(NONFRAC_DIR, f)).size[0])
    except: pass
ax.hist(widths, bins=25, color='steelblue', edgecolor='white', alpha=0.85)
if widths:
    ax.axvline(np.mean(widths), color='red', linestyle='--',
               label=f'Mean: {np.mean(widths):.0f}px')
ax.set_title('Image Width Distribution (sample)', fontweight='bold')
ax.set_xlabel('Width (pixels)')
ax.set_ylabel('Count')
ax.legend()
ax.spines[['top', 'right']].set_visible(False)

# Sample fractured images with bbox
sample_frac = random.sample(frac_files, min(3, len(frac_files)))
for i, fname in enumerate(sample_frac):
    img = np.array(Image.open(os.path.join(FRAC_DIR, fname)).convert('RGB'))
    axes[1, i].imshow(img)
    axes[1, i].set_title('🔴 Fractured', fontweight='bold', color='#E74C3C')
    axes[1, i].axis('off')
    if fname in fname_to_anns:
        ann = fname_to_anns[fname][0]
        x, y, w, h = ann['bbox']
        sx = img.shape[1] / ann['orig_w']
        sy = img.shape[0] / ann['orig_h']
        rect = patches.Rectangle((x*sx, y*sy), w*sx, h*sy,
                                   linewidth=2, edgecolor='yellow', facecolor='none')
        axes[1, i].add_patch(rect)
        axes[1, i].set_title('🔴 Fractured (bbox)', fontweight='bold', color='#E74C3C')

plt.tight_layout()
plt.savefig('/content/01_data_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/01_data_analysis.png")

# 8. BUILD DATASET LIST
import csv
fname_to_bp = {}
CSV_PATH = os.path.join(DATASET_DIR, 'dataset.csv')
if os.path.exists(CSV_PATH):
    with open(CSV_PATH, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            if row.get('mixed', '0') == '1':
                bp = 'mixed'
            else:
                bps = [b for b in ['hand', 'leg', 'hip', 'shoulder'] if row.get(b, '0') == '1']
                bp = bps[0] if bps else 'unknown'
            fname_to_bp[row['image_id']] = bp
else:
    print("The dataset.csv file was not found; it will be assumed that all parts 'unknown'")

all_data = []
for f in frac_files:
    bp = fname_to_bp.get(f, 'unknown')
    all_data.append({'path': os.path.join(FRAC_DIR, f), 'label': 1, 'fname': f, 'bp': bp, 'combined_label': f"1_{bp}"})
for f in nonfrac_files:
    bp = fname_to_bp.get(f, 'unknown')
    all_data.append({'path': os.path.join(NONFRAC_DIR, f), 'label': 0, 'fname': f, 'bp': bp, 'combined_label': f"0_{bp}"})
random.shuffle(all_data)

# 9. CLASS DISTRIBUTION
frac_data    = [d for d in all_data if d['label'] == 1]
nonfrac_data = [d for d in all_data if d['label'] == 0]
print(f"\n Fractured: {len(frac_data)} | Non-Fractured: {len(nonfrac_data)}")
print(f"   (Sample weights will be used to address imbalances in fractures and body parts)")


# 10. TRAIN / VAL / TEST SPLIT  70 / 15 / 15
labels_all = [d['combined_label'] for d in all_data]
from collections import Counter
counts = Counter(labels_all)
safe_labels_all = [l if counts[l] >= 4 else f"{l.split('_')[0]}_rare" for l in labels_all]

train_data, temp_data = train_test_split(all_data, test_size=0.30,
                                          stratify=safe_labels_all, random_state=SEED)

labels_temp = [d['combined_label'] for d in temp_data]
counts_temp = Counter(labels_temp)
safe_labels_temp = [l if counts_temp[l] >= 2 else f"{l.split('_')[0]}_rare" for l in labels_temp]

val_data, test_data = train_test_split(temp_data, test_size=0.50,
                                        stratify=safe_labels_temp, random_state=SEED)
print(f"\n Train:{len(train_data)} | Val:{len(val_data)} | Test:{len(test_data)}")

# 11. DATA AUGMENTATION
aug_train = A.Compose([
    A.Resize(IMG_H, IMG_W),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomRotate90(p=0.3),
    A.ShiftScaleRotate(shift_limit=0.08, scale_limit=0.12, rotate_limit=15, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.5),
    A.GaussianBlur(blur_limit=(3, 5), p=0.2),
    A.GridDistortion(num_steps=5, distort_limit=0.15, p=0.2),
    A.CLAHE(clip_limit=2.0, p=0.3),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])
aug_val = A.Compose([
    A.Resize(IMG_H, IMG_W),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])

# Augmentation preview
sample_path = os.path.join(FRAC_DIR, frac_files[0])
sample_img  = cv2.cvtColor(cv2.imread(sample_path), cv2.COLOR_BGR2RGB)
fig, axes   = plt.subplots(1, 6, figsize=(20, 4))
fig.suptitle(' Data Augmentation Examples', fontweight='bold', fontsize=14)
axes[0].imshow(cv2.resize(sample_img, IMG_SIZE))
axes[0].set_title('Original', fontweight='bold'); axes[0].axis('off')
for i in range(1, 6):
    aug_img = aug_train(image=sample_img)['image']
    vis = np.clip(aug_img * np.array([0.229,0.224,0.225]) + np.array([0.485,0.456,0.406]), 0, 1)
    axes[i].imshow(vis)
    axes[i].set_title(f'Aug #{i}', fontweight='bold'); axes[i].axis('off')
plt.tight_layout()
plt.savefig('/content/02_augmentation.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/02_augmentation.png")

# 12. HELPER FUNCTIONS
def polygon_to_mask(fname, h, w):
    mask = np.zeros((h, w), dtype=np.float32)
    if fname not in fname_to_anns:
        return mask[..., np.newaxis]
    for ann in fname_to_anns[fname]:
        sx = w / ann['orig_w']
        sy = h / ann['orig_h']
        for seg in ann['segmentation']:
            pts = np.array(seg, dtype=np.float32).reshape(-1, 2)
            pts[:, 0] *= sx
            pts[:, 1] *= sy
            cv2.fillPoly(mask, [pts.astype(np.int32)], 1.0)
    return mask[..., np.newaxis]

def get_bbox(fname):
    if fname not in fname_to_anns:
        return np.array([0., 0., 0., 0.], dtype=np.float32)
    ann = fname_to_anns[fname][0]
    x, y, w, h = ann['bbox']
    ow, oh = ann['orig_w'], ann['orig_h']
    return np.array([(x+w/2)/ow, (y+h/2)/oh, w/ow, h/oh], dtype=np.float32)

# 13. TF DATA PIPELINE (NATIVE & OPTIMIZED)
from sklearn.utils.class_weight import compute_class_weight
train_labels_list = [d['combined_label'] for d in train_data]
unique_labels = np.unique(train_labels_list)
cw = compute_class_weight('balanced', classes=unique_labels, y=train_labels_list)
class_weight_dict = dict(zip(unique_labels, cw))

print("\n  Sample Weights (To compensate for the lack of images of the pelvis and shoulder):")
for k, v in class_weight_dict.items():
    print(f"   - {k}: {v:.3f}")

def process_data(path, label, fname):
    def _process(path_b, label_b, fname_b):
        path_str = path_b.decode('utf-8')
        fname_str = fname_b.decode('utf-8')

        img = cv2.imread(path_str)
        if img is None:
            img = np.zeros((IMG_H, IMG_W, 3), dtype=np.uint8)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMG_W, IMG_H))

        lbl = np.float32(label_b)
        box = get_bbox(fname_str)
        msk = polygon_to_mask(fname_str, IMG_H, IMG_W)
        return img, lbl, box, msk

    img, lbl, box, msk = tf.numpy_function(
        _process,
        [path, label, fname],
        [tf.uint8, tf.float32, tf.float32, tf.float32]
    )
    img.set_shape([IMG_H, IMG_W, 3])
    lbl.set_shape([])
    box.set_shape([4])
    msk.set_shape([IMG_H, IMG_W, 1])
    return img, lbl, box, msk

def augment_data(img, lbl, box, msk, weight, augment):
    def _aug(img_np):
        if augment:
            tfm = aug_train(image=img_np)
        else:
            tfm = aug_val(image=img_np)
        return tfm['image'].astype(np.float32)

    img_aug = tf.numpy_function(_aug, [img], tf.float32)
    img_aug.set_shape([IMG_H, IMG_W, 3])

    targets = (lbl, box, msk)
    sample_weights = (
        tf.cast(weight, tf.float32),
        tf.constant(1.0, dtype=tf.float32),
        tf.ones((1, 1), dtype=tf.float32)
    )
    return img_aug, targets, sample_weights

def build_ds(data_list, augment=False, shuffle=False):
    paths   = [d['path'] for d in data_list]
    labels  = [d['label'] for d in data_list]
    fnames  = [d['fname'] for d in data_list]
    weights = [class_weight_dict[d['combined_label']] for d in data_list]

    ds = tf.data.Dataset.from_tensor_slices((paths, labels, fnames, weights))

    if shuffle:
        ds = ds.shuffle(len(data_list), seed=SEED)

    ds = ds.map(lambda p, l, f, w: (*process_data(p, l, f), w), num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.cache()

    ds = ds.map(lambda img, lbl, box, msk, w: augment_data(img, lbl, box, msk, w, augment), num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

print("\n Building NATIVE TF datasets...")
train_ds = build_ds(train_data, augment=True,  shuffle=True)
val_ds   = build_ds(val_data,   augment=False, shuffle=False)
test_ds  = build_ds(test_data,  augment=False, shuffle=False)
print(" Datasets ready")

# 14. MODEL  ← التعديل الوحيد: إضافة L2 على Dense layers في Head 1 و Head 2
def build_fracturenet(freeze=True, model_choice='EfficientNetB0'):
    inputs   = keras.Input(shape=(IMG_H, IMG_W, 3), name='input')

    backbone_map = {
        'EfficientNetB0': EfficientNetB0,
        'EfficientNetB3': EfficientNetB3,
        'EfficientNetB4': EfficientNetB4,
        'ResNet50V2'    : ResNet50V2,
        'DenseNet121'   : DenseNet121,
    }
    if model_choice not in backbone_map:
        raise ValueError(f" Backbone Unsupported: {model_choice}. "
                         f"Options: {list(backbone_map.keys())}")

    BackboneClass = backbone_map[model_choice]
    backbone = BackboneClass(include_top=False, weights='imagenet', input_tensor=inputs)
    backbone.trainable = not freeze
    feat = backbone.output
    print(f" Backbone: {model_choice} → feature shape: {feat.shape}")

    reg = regularizers.l2(L2_REG)                              # ← إنشاء L2 regularizer

    # Head 1: Classification — رفع Dropout لتقليل False Positives
    cls = layers.GlobalAveragePooling2D()(feat)
    cls = layers.Dense(512, activation='relu', kernel_regularizer=reg)(cls)  # ← L2
    cls = layers.BatchNormalization()(cls)
    cls = layers.Dropout(0.55)(cls)                            # ← رُفع من 0.45 إلى 0.55
    cls = layers.Dense(128, activation='relu', kernel_regularizer=reg)(cls)  # ← L2
    cls = layers.Dropout(0.4)(cls)                             # ← رُفع من 0.3 إلى 0.4
    cls_out = layers.Dense(1, activation='sigmoid', dtype='float32', name='cls_out')(cls)

    # Head 2: Localization
    loc = layers.GlobalAveragePooling2D()(feat)
    loc = layers.Dense(256, activation='relu', kernel_regularizer=reg)(loc)  # ← L2
    loc = layers.BatchNormalization()(loc)
    loc = layers.Dropout(0.3)(loc)
    loc = layers.Dense(64, activation='relu', kernel_regularizer=reg)(loc)   # ← L2
    loc_out = layers.Dense(4, activation='sigmoid', dtype='float32', name='loc_out')(loc)

    # Head 3: Segmentation (5× upsample 7→224) — بدون تعديل
    seg = layers.Conv2DTranspose(512, 3, strides=2, padding='same', activation='relu')(feat)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(64,  3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(32,  3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.Conv2D(16, 3, padding='same', activation='relu')(seg)
    seg_out = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32', name='seg_out')(seg)

    return Model(inputs, [cls_out, loc_out, seg_out], name=f'FractureNet_{model_choice}'), backbone

def focal_loss(gamma=2.0, alpha=0.75):
    """
    Focal Loss لمعالجة class imbalance وتحسين Precision على الـ Fractured class.
    alpha=0.75  → يعطي وزناً أعلى للـ Non-Fractured لتقليل False Positives
    gamma=2.0   → يُركّز التعلّم على الأمثلة الصعبة
    """
    def loss_fn(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        bce    = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        p_t    = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        alpha_t = y_true * alpha + (1 - y_true) * (1 - alpha)
        focal_w = alpha_t * tf.pow(1.0 - p_t, gamma)
        return tf.reduce_mean(focal_w * bce)
    return loss_fn

def compile_model(model, lr):
    model.compile(
        optimizer=keras.optimizers.Adam(lr),
        loss={'cls_out': focal_loss(gamma=2.0, alpha=0.75),    # ← Focal Loss بدل binary_crossentropy
              'loc_out': 'mse',
              'seg_out': 'binary_crossentropy'},
        loss_weights={'cls_out': 3.0,                          # ← رُفع من 2.0 إلى 3.0
                      'loc_out': 0.5,
                      'seg_out': 1.0},
        metrics={'cls_out': [keras.metrics.BinaryAccuracy(name='acc'),
                             keras.metrics.AUC(name='auc')],
                 'loc_out': ['mae'],
                 'seg_out': [keras.metrics.BinaryAccuracy(name='acc'),
                             keras.metrics.MeanIoU(num_classes=2, name='iou')]}
    )

print(f"\n  Building FractureNet with {MODEL_CHOICE}...")
model, backbone = build_fracturenet(freeze=True, model_choice=MODEL_CHOICE)
model.summary(line_length=100)

# 15. CALLBACKS
ckpt_path = '/content/best_fracturenet.keras'

def get_callbacks(patience_es, patience_lr):
    return [
        ModelCheckpoint(ckpt_path, monitor='val_cls_out_auc',
                        mode='max', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_cls_out_auc', patience=patience_es,
                      restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', patience=patience_lr,
                          factor=0.5, min_lr=1e-8, verbose=1),
    ]

# 17. PHASE 1: FROZEN BACKBONE — 5 epochs
print("\n" + "="*60)
print(f" PHASE 1 — {MODEL_CHOICE} frozen | LR=1e-3 | Epochs 1-{EPOCHS//2}")
print("="*60)
compile_model(model, LR_PHASE1)
history1 = model.fit(train_ds, validation_data=val_ds,
                      epochs=EPOCHS//2, callbacks=get_callbacks(4, 2), verbose=1)

# 18. PHASE 2: FINE-TUNE — 5 epochs
freeze_map = {
    'EfficientNetB0': 100,
    'EfficientNetB3': 130,
    'EfficientNetB4': 150,
    'ResNet50V2'    : 100,
    'DenseNet121'   : 300,
}
freeze_n = freeze_map.get(MODEL_CHOICE, 100)

print("\n" + "="*60)
print(f" PHASE 2 — Fine-tune (freeze first {freeze_n} layers) | LR={LR_PHASE2} | Epochs {EPOCHS//2+1}-{EPOCHS}")
print("="*60)
backbone.trainable = True
for layer in backbone.layers[:freeze_n]:
    layer.trainable = False
compile_model(model, LR_PHASE2)
history2 = model.fit(train_ds, validation_data=val_ds,
                      epochs=EPOCHS//2, callbacks=get_callbacks(5, 3), verbose=1)

# 19. PLOT TRAINING HISTORY
def merge_hist(h1, h2):
    return {k: h1.history[k] + h2.history[k] for k in h1.history}

H          = merge_hist(history1, history2)
n_ep       = len(H['loss'])
ep_range   = range(1, n_ep + 1)
phase_line = EPOCHS // 2

metrics_plot = [
    ('loss',          'val_loss',          'Total Loss',              '#E74C3C'),
    ('cls_out_acc',   'val_cls_out_acc',   'Classification Accuracy', '#3498DB'),
    ('cls_out_auc',   'val_cls_out_auc',   'Classification AUC',      '#9B59B6'),
    ('loc_out_mae',   'val_loc_out_mae',   'Localization MAE',         '#F39C12'),
    ('seg_out_acc',   'val_seg_out_acc',   'Segmentation Accuracy',   '#27AE60'),
    ('seg_out_iou',   'val_seg_out_iou',   'Segmentation IoU',         '#1ABC9C'),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle(f' FractureNet ({MODEL_CHOICE}) — Training History ({n_ep} Epochs)',
              fontsize=16, fontweight='bold')
axes = axes.flatten()

for idx, (tk, vk, title, color) in enumerate(metrics_plot):
    ax = axes[idx]
    if tk not in H:
        ax.set_visible(False); continue
    ax.plot(ep_range, H[tk], label='Train', color=color, lw=2.5, marker='o', ms=3)
    ax.plot(ep_range, H[vk], label='Val',   color=color, lw=2.5,
            linestyle='--', marker='s', ms=3, alpha=0.7)
    ax.axvline(phase_line + 0.5, color='gray', ls=':', lw=1.5, label='Phase 1→2')
    ax.set_title(title, fontweight='bold', fontsize=12)
    ax.set_xlabel('Epoch')
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.3)
    ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.savefig('/content/03_training_history.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/03_training_history.png")

# 19. EVALUATE ON TEST SET

print("\n" + "="*60)
print(" Test Set Evaluation")
print("="*60)
test_results = model.evaluate(test_ds, verbose=1)
print("\n Test Metrics:")
for name, val in zip(model.metrics_names, test_results):
    print(f"  {name:<35}: {val:.4f}")

y_true, y_prob, y_pred = [], [], []
for img_b, lbl_b, _ in test_ds:
    cp, _, _ = model.predict(img_b, verbose=0)
    y_true.extend(lbl_b[0].numpy().astype(int).tolist())
    y_prob.extend(cp.flatten().tolist())
    y_pred.extend((cp.flatten() > CLS_THRESHOLD).astype(int).tolist())  # ← threshold مُعدَّل

print(f"\n  Classification Threshold used: {CLS_THRESHOLD}")   # ← طباعة الـ threshold

print("\n Classification Report:")
print(classification_report(y_true, y_pred,
                             target_names=['Non-Fractured', 'Fractured']))
try:
    print(f" AUC-ROC: {roc_auc_score(y_true, y_prob):.4f}")
except Exception as e:
    print(f"AUC: {e}")

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Fractured', 'Fractured'],
            yticklabels=['Non-Fractured', 'Fractured'],
            ax=ax, linewidths=0.5, cbar_kws={'shrink': 0.8})
ax.set_title('Confusion Matrix — Test Set', fontweight='bold', fontsize=14, pad=15)
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
plt.tight_layout()
plt.savefig('/content/04_confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/04_confusion_matrix.png")

# 20. PREDICTION VISUALIZATION
def denorm(img):
    return np.clip(img * np.array([0.229,0.224,0.225]) + np.array([0.485,0.456,0.406]), 0, 1)

for img_b, lbl_b, _ in test_ds.take(1):
    cp, lp, sp = model.predict(img_b, verbose=0)
    break

cls_true = lbl_b[0].numpy()
loc_true = lbl_b[1].numpy()
seg_true = lbl_b[2].numpy()
n_show   = min(5, img_b.shape[0])

fig, axes = plt.subplots(n_show, 5, figsize=(22, 4.5 * n_show))
fig.suptitle(' FractureNet — Classification | Localization | Segmentation',
              fontsize=13, fontweight='bold', y=1.01)

for col, title in enumerate(['Original', 'GT BBox', 'Pred BBox', 'GT Mask', 'Pred Mask']):
    axes[0, col].set_title(title, fontweight='bold', fontsize=11)

for i in range(n_show):
    vis          = denorm(img_b[i].numpy())
    is_true_frac = cls_true[i] > 0.5
    is_pred_frac = cp[i][0]   > CLS_THRESHOLD                 # ← threshold مُعدَّل
    prob         = float(cp[i][0])

    # Col 0: Original
    axes[i, 0].imshow(vis)
    axes[i, 0].set_title('🔴 Fractured' if is_true_frac else '🟢 Normal', fontsize=9)
    axes[i, 0].axis('off')

    # Col 1: GT bbox
    axes[i, 1].imshow(vis)
    if is_true_frac and loc_true[i].sum() > 0:
        xc, yc, bw, bh = loc_true[i]
        rect = patches.Rectangle(((xc-bw/2)*IMG_W, (yc-bh/2)*IMG_H),
                                   bw*IMG_W, bh*IMG_H, lw=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect)
    axes[i, 1].axis('off')

    # Col 2: Pred bbox
    axes[i, 2].imshow(vis)
    if is_pred_frac:
        xc, yc, bw, bh = lp[i]
        rect = patches.Rectangle(((xc-bw/2)*IMG_W, (yc-bh/2)*IMG_H),
                                   bw*IMG_W, bh*IMG_H, lw=2, edgecolor='yellow', facecolor='none')
        axes[i, 2].add_patch(rect)
    axes[i, 2].set_title(f"{'🔴' if is_pred_frac else '🟢'} {prob:.1%}", fontsize=9)
    axes[i, 2].axis('off')

    # Col 3: GT mask
    axes[i, 3].imshow(vis)
    if seg_true[i].sum() > 0:
        axes[i, 3].imshow(seg_true[i,:,:,0], alpha=0.55, cmap='Reds', vmin=0, vmax=1)
    axes[i, 3].axis('off')

    # Col 4: Pred mask
    axes[i, 4].imshow(vis)
    pred_mask = sp[i,:,:,0]
    if pred_mask.max() > 0.1:
        axes[i, 4].imshow(pred_mask > 0.5, alpha=0.55, cmap='hot', vmin=0, vmax=1)
    axes[i, 4].axis('off')

plt.tight_layout()
plt.savefig('/content/05_predictions.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/05_predictions.png")

# 21. FINAL SUMMARY
best_auc = max(H.get('val_cls_out_auc', [0]))
best_ep  = np.argmax(H.get('val_cls_out_auc', [0])) + 1

print("\n╔" + "═"*58 + "╗")
print("║                TRAINING COMPLETE                        ║")
print("╠" + "═"*58 + "╣")
print(f"║  Original dataset : {total} images")
print(f"║  Training dataset : {len(train_data)} samples (no oversampling)")
print(f"║  Model            : FractureNet ({MODEL_CHOICE})")
print(f"║  Mixed Precision  : {tf.keras.mixed_precision.global_policy().name}")
print(f"║  L2 Regularization: {L2_REG}")
print(f"║  CLS Threshold    : {CLS_THRESHOLD}")
print(f"║  Epochs run       : {n_ep} (Phase1={n_ep//2} + Phase2={n_ep//2})")
print(f"║  Best Val AUC     : {best_auc:.4f}  (epoch {best_ep})")
print(f"║  Class Weights    : NonFrac={cw[0]:.3f} | Frac={cw[1]:.3f}")
print("║")
print("║   Outputs:")
print("║    /content/best_fracturenet.keras")
print("║    /content/01_data_analysis.png")
print("║    /content/02_augmentation.png")
print("║    /content/03_training_history.png")
print("║    /content/04_confusion_matrix.png")
print("║    /content/05_predictions.png")
print("╚" + "═"*58 + "╝")

# 22. CONFUSION MATRIX PER BODY PART
print("\n" + "="*60)
print(" Detailed Analysis: Confusion Matrix by Body Part")
print("="*60)

test_bps = [d['bp'] for d in test_data]
unique_bps = sorted(list(set(test_bps)))

fig, axes = plt.subplots(1, len(unique_bps), figsize=(4.5 * len(unique_bps), 4.5))
if len(unique_bps) == 1:
    axes = [axes]
fig.suptitle('Confusion Matrices per Body Part', fontsize=16, fontweight='bold', y=1.05)

for idx, bp in enumerate(unique_bps):
    bp_indices = [i for i, part in enumerate(test_bps) if part == bp]
    if len(bp_indices) == 0: continue

    bp_y_true = [y_true[i] for i in bp_indices]
    bp_y_pred = [y_pred[i] for i in bp_indices]

    print(f"\n{'='*20} [{bp.upper()}] {'='*20}")
    print(classification_report(bp_y_true, bp_y_pred, target_names=['Non-Fractured', 'Fractured'], zero_division=0))

    cm_bp = confusion_matrix(bp_y_true, bp_y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm_bp.ravel()

    acc = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0

    sns.heatmap(cm_bp, annot=True, fmt='d', cmap='Oranges',
                xticklabels=['Non-Frac', 'Frac'],
                yticklabels=['Non-Frac', 'Frac'],
                ax=axes[idx], linewidths=0.5, cbar=False)

    title_text = f'{bp.upper()} (n={len(bp_indices)})\nAcc: {acc:.1%} | Recall: {recall:.1%}'
    axes[idx].set_title(title_text, fontweight='bold', pad=10)
    axes[idx].set_xlabel('Predicted')
    if idx == 0:
        axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig('/content/06_cm_per_body_part.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/06_cm_per_body_part.png")
# Out:
#  TensorFlow : 2.20.0
#  GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#  Mixed Precision: mixed_float16
#  Model Choice   : DenseNet121
#  L2 Regularization: 0.0001
#  CLS Threshold    : 0.65
#  Google Drive Pre-assembled
# I found the file ZIP: /content/drive/MyDrive/archive (31).zip
#
# path ZIP: /content/drive/MyDrive/archive (31).zip
#
#  Extracting dataset...
#  Extraction complete
#  Dataset path: /content/extracted_dataset/FracAtlas
#  All dataset paths verified
#
#  Normalizing image extensions...
#   Converted 0 files in Fractured
#   Skipping IMG0004028.jpg: image file is truncated (20 bytes not processed)
#   Skipping IMG0004036.jpg: image file is truncated (14 bytes not processed)
#   Skipping IMG0004154.jpg: image file is truncated (22 bytes not processed)
#   Skipping IMG0004121.jpg: image file is truncated (40 bytes not processed)
#   Skipping IMG0004298.jpg: image file is truncated (19 bytes not processed)
#   Skipping IMG0004170.jpg: image file is truncated (11 bytes not processed)
#   Skipping IMG0004177.jpg: image file is truncated (34 bytes not processed)
#   Skipping IMG0004227.jpg: image file is truncated (30 bytes not processed)
#   Skipping IMG0004173.jpg: image file is truncated (0 bytes not processed)
#   Skipping IMG0004304.jpg: image file is truncated (22 bytes not processed)
#   Skipping IMG0004070.jpg: image file is truncated (41 bytes not processed)
#   Skipping IMG0004098.jpg: image file is truncated (17 bytes not processed)
#   Skipping IMG0004308.jpg: image file is truncated (40 bytes not processed)
#   Skipping IMG0004194.jpg: image file is truncated (10 bytes not processed)
#   Skipping IMG0004251.jpg: image file is truncated (19 bytes not processed)
#   Skipping IMG0004174.jpg: image file is truncated (4 bytes not processed)
#   Skipping IMG0004189.jpg: image file is truncated (16 bytes not processed)
#   Skipping IMG0004120.jpg: image file is truncated (8 bytes not processed)
#   Skipping IMG0004109.jpg: image file is truncated (5 bytes not processed)
#   Skipping IMG0004148.jpg: image file is truncated (14 bytes not processed)
#   Skipping IMG0004149.jpg: image file is truncated (33 bytes not processed)
#   Skipping IMG0004263.jpg: image file is truncated (24 bytes not processed)
#   Skipping IMG0004273.jpg: image file is truncated (8 bytes not processed)
#   Skipping IMG0004228.jpg: image file is truncated (17 bytes not processed)
#   Skipping IMG0004279.jpg: image file is truncated (5 bytes not processed)
#   Skipping IMG0004145.jpg: image file is truncated (10 bytes not processed)
#   Skipping IMG0004285.jpg: image file is truncated (9 bytes not processed)
#   Skipping IMG0004291.jpg: image file is truncated (13 bytes not processed)
#   Skipping IMG0004079.jpg: image file is truncated (24 bytes not processed)
#   Skipping IMG0004142.jpg: image file is truncated (32 bytes not processed)
#   Skipping IMG0004129.jpg: image file is truncated (6 bytes not processed)
#   Skipping IMG0004100.jpg: image file is truncated (15 bytes not processed)
#   Skipping IMG0004297.jpg: image file is truncated (5 bytes not processed)
#   Skipping IMG0004258.jpg: image file is truncated (0 bytes not processed)
#   Skipping IMG0004029.jpg: image file is truncated (22 bytes not processed)
#   Skipping IMG0004347.jpg: image file is truncated (40 bytes not processed)
#   Skipping IMG0004286.jpg: image file is truncated (46 bytes not processed)
#   Skipping IMG0004073.jpg: image file is truncated (3 bytes not processed)
#   Skipping IMG0004119.jpg: image file is truncated (6 bytes not processed)
#   Skipping IMG0004255.jpg: image file is truncated (20 bytes not processed)
#   Skipping IMG0004122.jpg: image file is truncated (26 bytes not processed)
#   Skipping IMG0004123.jpg: image file is truncated (17 bytes not processed)
#   Skipping IMG0004134.jpg: image file is truncated (1 bytes not processed)
#   Skipping IMG0004256.jpg: image file is truncated (66 bytes not processed)
#   Skipping IMG0004226.jpg: image file is truncated (23 bytes not processed)
#   Skipping IMG0004275.jpg: image file is truncated (24 bytes not processed)
#   Skipping IMG0004143.jpg: image file is truncated (10 bytes not processed)
#   Skipping IMG0004076.jpg: image file is truncated (0 bytes not processed)
#   Skipping IMG0004092.jpg: image file is truncated (3 bytes not processed)
#   Skipping IMG0004252.jpg: image file is truncated (67 bytes not processed)
#   Skipping IMG0004278.jpg: image file is truncated (29 bytes not processed)
#   Skipping IMG0004155.jpg: image file is truncated (18 bytes not processed)
#   Skipping IMG0004288.jpg: image file is truncated (1 bytes not processed)
#   Skipping IMG0004084.jpg: image file is truncated (5 bytes not processed)
#   Skipping IMG0004169.jpg: image file is truncated (14 bytes not processed)
#   Skipping IMG0004290.jpg: image file is truncated (54 bytes not processed)
#   Skipping IMG0004159.jpg: image file is truncated (8 bytes not processed)
#   Skipping IMG0004130.jpg: image file is truncated (8 bytes not processed)
#   Skipping IMG0004259.jpg: image file is truncated (7 bytes not processed)
#   Converted 0 files in Non_fractured
#
#  Loaded 922 annotations for 717 fractured images
#
# ==================================================
#   Fractured    :   717  (17.6%)
#   Non-Fractured:  3366  (82.4%)
#   Total        :  4083
#   Imbalance    : 1:4
# ==================================================
#  Saved: /content/01_data_analysis.png
#
#  Fractured: 717 | Non-Fractured: 3366
#    (Sample weights will be used to address imbalances in fractures and body parts)
#
#  Train:2858 | Val:612 | Test:613
#  Saved: /content/02_augmentation.png
#
#   Sample Weights (To compensate for the lack of images of the pelvis and shoulder):
#    - 0_hand: 0.453
#    - 0_hip: 2.422
#    - 0_leg: 0.214
#    - 0_mixed: 1.394
#    - 0_shoulder: 4.466
#    - 1_hand: 1.078
#    - 1_hip: 40.829
#    - 1_leg: 1.918
#    - 1_mixed: 3.862
#    - 1_shoulder: 40.829
#
#  Building NATIVE TF datasets...
#  Datasets ready
#
#   Building FractureNet with DenseNet121...
#  Backbone: DenseNet121 → feature shape: (None, 7, 7, 1024)
# Model: "FractureNet_DenseNet121"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)          │ (None, 224, 224, 3)     │              0 │ -                       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ zero_padding2d_2            │ (None, 230, 230, 3)     │              0 │ input[0][0]             │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_conv (Conv2D)         │ (None, 112, 112, 64)    │          9,408 │ zero_padding2d_2[0][0]  │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_bn                    │ (None, 112, 112, 64)    │            256 │ conv1_conv[0][0]        │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv1_relu (Activation)     │ (None, 112, 112, 64)    │              0 │ conv1_bn[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ zero_padding2d_3            │ (None, 114, 114, 64)    │              0 │ conv1_relu[0][0]        │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool1 (MaxPooling2D)        │ (None, 56, 56, 64)      │              0 │ zero_padding2d_3[0][0]  │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_0_bn           │ (None, 56, 56, 64)      │            256 │ pool1[0][0]             │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_0_relu         │ (None, 56, 56, 64)      │              0 │ conv2_block1_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_1_conv         │ (None, 56, 56, 128)     │          8,192 │ conv2_block1_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block1_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block1_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block1_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block1_concat         │ (None, 56, 56, 96)      │              0 │ pool1[0][0],            │
# │ (Concatenate)               │                         │                │ conv2_block1_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_0_bn           │ (None, 56, 56, 96)      │            384 │ conv2_block1_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_0_relu         │ (None, 56, 56, 96)      │              0 │ conv2_block2_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_1_conv         │ (None, 56, 56, 128)     │         12,288 │ conv2_block2_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block2_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block2_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block2_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block2_concat         │ (None, 56, 56, 128)     │              0 │ conv2_block1_concat[0]… │
# │ (Concatenate)               │                         │                │ conv2_block2_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_0_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block2_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_0_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block3_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_1_conv         │ (None, 56, 56, 128)     │         16,384 │ conv2_block3_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block3_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block3_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block3_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block3_concat         │ (None, 56, 56, 160)     │              0 │ conv2_block2_concat[0]… │
# │ (Concatenate)               │                         │                │ conv2_block3_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_0_bn           │ (None, 56, 56, 160)     │            640 │ conv2_block3_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_0_relu         │ (None, 56, 56, 160)     │              0 │ conv2_block4_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_1_conv         │ (None, 56, 56, 128)     │         20,480 │ conv2_block4_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block4_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block4_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block4_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block4_concat         │ (None, 56, 56, 192)     │              0 │ conv2_block3_concat[0]… │
# │ (Concatenate)               │                         │                │ conv2_block4_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_0_bn           │ (None, 56, 56, 192)     │            768 │ conv2_block4_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_0_relu         │ (None, 56, 56, 192)     │              0 │ conv2_block5_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_1_conv         │ (None, 56, 56, 128)     │         24,576 │ conv2_block5_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block5_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block5_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block5_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block5_concat         │ (None, 56, 56, 224)     │              0 │ conv2_block4_concat[0]… │
# │ (Concatenate)               │                         │                │ conv2_block5_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_0_bn           │ (None, 56, 56, 224)     │            896 │ conv2_block5_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_0_relu         │ (None, 56, 56, 224)     │              0 │ conv2_block6_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_1_conv         │ (None, 56, 56, 128)     │         28,672 │ conv2_block6_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_1_bn           │ (None, 56, 56, 128)     │            512 │ conv2_block6_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_1_relu         │ (None, 56, 56, 128)     │              0 │ conv2_block6_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_2_conv         │ (None, 56, 56, 32)      │         36,864 │ conv2_block6_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv2_block6_concat         │ (None, 56, 56, 256)     │              0 │ conv2_block5_concat[0]… │
# │ (Concatenate)               │                         │                │ conv2_block6_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool2_bn                    │ (None, 56, 56, 256)     │          1,024 │ conv2_block6_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool2_relu (Activation)     │ (None, 56, 56, 256)     │              0 │ pool2_bn[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool2_conv (Conv2D)         │ (None, 56, 56, 128)     │         32,768 │ pool2_relu[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool2_pool                  │ (None, 28, 28, 128)     │              0 │ pool2_conv[0][0]        │
# │ (AveragePooling2D)          │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_0_bn           │ (None, 28, 28, 128)     │            512 │ pool2_pool[0][0]        │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_0_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block1_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_1_conv         │ (None, 28, 28, 128)     │         16,384 │ conv3_block1_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block1_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block1_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block1_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block1_concat         │ (None, 28, 28, 160)     │              0 │ pool2_pool[0][0],       │
# │ (Concatenate)               │                         │                │ conv3_block1_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_0_bn           │ (None, 28, 28, 160)     │            640 │ conv3_block1_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_0_relu         │ (None, 28, 28, 160)     │              0 │ conv3_block2_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_1_conv         │ (None, 28, 28, 128)     │         20,480 │ conv3_block2_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block2_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block2_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block2_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block2_concat         │ (None, 28, 28, 192)     │              0 │ conv3_block1_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block2_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_0_bn           │ (None, 28, 28, 192)     │            768 │ conv3_block2_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_0_relu         │ (None, 28, 28, 192)     │              0 │ conv3_block3_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_1_conv         │ (None, 28, 28, 128)     │         24,576 │ conv3_block3_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block3_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block3_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block3_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block3_concat         │ (None, 28, 28, 224)     │              0 │ conv3_block2_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block3_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_0_bn           │ (None, 28, 28, 224)     │            896 │ conv3_block3_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_0_relu         │ (None, 28, 28, 224)     │              0 │ conv3_block4_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_1_conv         │ (None, 28, 28, 128)     │         28,672 │ conv3_block4_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block4_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block4_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block4_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block4_concat         │ (None, 28, 28, 256)     │              0 │ conv3_block3_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block4_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_0_bn           │ (None, 28, 28, 256)     │          1,024 │ conv3_block4_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_0_relu         │ (None, 28, 28, 256)     │              0 │ conv3_block5_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_1_conv         │ (None, 28, 28, 128)     │         32,768 │ conv3_block5_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block5_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block5_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block5_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block5_concat         │ (None, 28, 28, 288)     │              0 │ conv3_block4_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block5_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_0_bn           │ (None, 28, 28, 288)     │          1,152 │ conv3_block5_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_0_relu         │ (None, 28, 28, 288)     │              0 │ conv3_block6_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_1_conv         │ (None, 28, 28, 128)     │         36,864 │ conv3_block6_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block6_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block6_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block6_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block6_concat         │ (None, 28, 28, 320)     │              0 │ conv3_block5_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block6_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_0_bn           │ (None, 28, 28, 320)     │          1,280 │ conv3_block6_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_0_relu         │ (None, 28, 28, 320)     │              0 │ conv3_block7_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_1_conv         │ (None, 28, 28, 128)     │         40,960 │ conv3_block7_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block7_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block7_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block7_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block7_concat         │ (None, 28, 28, 352)     │              0 │ conv3_block6_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block7_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_0_bn           │ (None, 28, 28, 352)     │          1,408 │ conv3_block7_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_0_relu         │ (None, 28, 28, 352)     │              0 │ conv3_block8_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_1_conv         │ (None, 28, 28, 128)     │         45,056 │ conv3_block8_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block8_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block8_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block8_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block8_concat         │ (None, 28, 28, 384)     │              0 │ conv3_block7_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block8_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_0_bn           │ (None, 28, 28, 384)     │          1,536 │ conv3_block8_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_0_relu         │ (None, 28, 28, 384)     │              0 │ conv3_block9_0_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_1_conv         │ (None, 28, 28, 128)     │         49,152 │ conv3_block9_0_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_1_bn           │ (None, 28, 28, 128)     │            512 │ conv3_block9_1_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_1_relu         │ (None, 28, 28, 128)     │              0 │ conv3_block9_1_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_2_conv         │ (None, 28, 28, 32)      │         36,864 │ conv3_block9_1_relu[0]… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block9_concat         │ (None, 28, 28, 416)     │              0 │ conv3_block8_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block9_2_conv[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_0_bn          │ (None, 28, 28, 416)     │          1,664 │ conv3_block9_concat[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_0_relu        │ (None, 28, 28, 416)     │              0 │ conv3_block10_0_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_1_conv        │ (None, 28, 28, 128)     │         53,248 │ conv3_block10_0_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_1_bn          │ (None, 28, 28, 128)     │            512 │ conv3_block10_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_1_relu        │ (None, 28, 28, 128)     │              0 │ conv3_block10_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_2_conv        │ (None, 28, 28, 32)      │         36,864 │ conv3_block10_1_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block10_concat        │ (None, 28, 28, 448)     │              0 │ conv3_block9_concat[0]… │
# │ (Concatenate)               │                         │                │ conv3_block10_2_conv[0… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_0_bn          │ (None, 28, 28, 448)     │          1,792 │ conv3_block10_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_0_relu        │ (None, 28, 28, 448)     │              0 │ conv3_block11_0_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_1_conv        │ (None, 28, 28, 128)     │         57,344 │ conv3_block11_0_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_1_bn          │ (None, 28, 28, 128)     │            512 │ conv3_block11_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_1_relu        │ (None, 28, 28, 128)     │              0 │ conv3_block11_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_2_conv        │ (None, 28, 28, 32)      │         36,864 │ conv3_block11_1_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block11_concat        │ (None, 28, 28, 480)     │              0 │ conv3_block10_concat[0… │
# │ (Concatenate)               │                         │                │ conv3_block11_2_conv[0… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_0_bn          │ (None, 28, 28, 480)     │          1,920 │ conv3_block11_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_0_relu        │ (None, 28, 28, 480)     │              0 │ conv3_block12_0_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_1_conv        │ (None, 28, 28, 128)     │         61,440 │ conv3_block12_0_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_1_bn          │ (None, 28, 28, 128)     │            512 │ conv3_block12_1_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_1_relu        │ (None, 28, 28, 128)     │              0 │ conv3_block12_1_bn[0][… │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_2_conv        │ (None, 28, 28, 32)      │         36,864 │ conv3_block12_1_relu[0… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ conv3_block12_concat        │ (None, 28, 28, 512)     │              0 │ conv3_block11_concat[0… │
# │ (Concatenate)               │                         │                │ conv3_block12_2_conv[0… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool3_bn                    │ (None, 28, 28, 512)     │          2,048 │ conv3_block12_concat[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool3_relu (Activation)     │ (None, 28, 28, 512)     │              0 │ pool3_bn[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ pool3_conv (Conv2D)         │ (None, 28, 28, 256)     │        131,072 │ pool3_relu[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# ...
# Epoch 15/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - cls_out_acc: 0.8019 - cls_out_auc: 0.8303 - cls_out_loss: 0.0409 - loc_out_loss: 0.0125 - loc_out_mae: 0.0571 - loss: 0.1849 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0052
# Epoch 15: val_cls_out_auc improved from 0.90743 to 0.90998, saving model to /content/best_fracturenet.keras
#
# Epoch 15: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - cls_out_acc: 0.7985 - cls_out_auc: 0.8188 - cls_out_loss: 0.0458 - loc_out_loss: 0.0136 - loc_out_mae: 0.0598 - loss: 0.1991 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0056 - val_cls_out_acc: 0.8644 - val_cls_out_auc: 0.9100 - val_cls_out_loss: 0.0363 - val_loc_out_loss: 0.0154 - val_loc_out_mae: 0.0726 - val_loss: 0.1734 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0050 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 15.
#
# ============================================================
#  PHASE 2 — Fine-tune (freeze first 300 layers) | LR=5e-05 | Epochs 16-30
# ============================================================
# Epoch 1/15
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - cls_out_acc: 0.7675 - cls_out_auc: 0.8039 - cls_out_loss: 0.0440 - loc_out_loss: 0.0145 - loc_out_mae: 0.0623 - loss: 0.1939 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0055
# Epoch 1: val_cls_out_auc improved from None to 0.88343, saving model to /content/best_fracturenet.keras
#
# Epoch 1: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 249s 750ms/step - cls_out_acc: 0.7768 - cls_out_auc: 0.8134 - cls_out_loss: 0.0460 - loc_out_loss: 0.0143 - loc_out_mae: 0.0607 - loss: 0.1985 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0059 - val_cls_out_acc: 0.8971 - val_cls_out_auc: 0.8834 - val_cls_out_loss: 0.0473 - val_loc_out_loss: 0.0123 - val_loc_out_mae: 0.0443 - val_loss: 0.2022 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 5.0000e-05
# Epoch 2/15
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.7886 - cls_out_auc: 0.8536 - cls_out_loss: 0.0384 - loc_out_loss: 0.0122 - loc_out_mae: 0.0545 - loss: 0.1727 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0055
# Epoch 2: val_cls_out_auc improved from 0.88343 to 0.89438, saving model to /content/best_fracturenet.keras
#
# Epoch 2: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 34s 187ms/step - cls_out_acc: 0.7922 - cls_out_auc: 0.8407 - cls_out_loss: 0.0438 - loc_out_loss: 0.0127 - loc_out_mae: 0.0552 - loss: 0.1881 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0059 - val_cls_out_acc: 0.9036 - val_cls_out_auc: 0.8944 - val_cls_out_loss: 0.0540 - val_loc_out_loss: 0.0132 - val_loc_out_mae: 0.0432 - val_loss: 0.2211 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0048 - learning_rate: 5.0000e-05
# Epoch 3/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - cls_out_acc: 0.8097 - cls_out_auc: 0.8635 - cls_out_loss: 0.0380 - loc_out_loss: 0.0113 - loc_out_mae: 0.0508 - loss: 0.1692 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0054
# Epoch 3: val_cls_out_auc improved from 0.89438 to 0.90078, saving model to /content/best_fracturenet.keras
#
# Epoch 3: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 31s 171ms/step - cls_out_acc: 0.8135 - cls_out_auc: 0.8629 - cls_out_loss: 0.0414 - loc_out_loss: 0.0119 - loc_out_mae: 0.0519 - loss: 0.1783 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0057 - val_cls_out_acc: 0.8824 - val_cls_out_auc: 0.9008 - val_cls_out_loss: 0.0422 - val_loc_out_loss: 0.0123 - val_loc_out_mae: 0.0476 - val_loss: 0.1830 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 5.0000e-05
# Epoch 4/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - cls_out_acc: 0.8236 - cls_out_auc: 0.8840 - cls_out_loss: 0.0349 - loc_out_loss: 0.0110 - loc_out_mae: 0.0503 - loss: 0.1583 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0053
# Epoch 4: val_cls_out_auc improved from 0.90078 to 0.90806, saving model to /content/best_fracturenet.keras
#
# Epoch 4: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 29s 160ms/step - cls_out_acc: 0.8184 - cls_out_auc: 0.8757 - cls_out_loss: 0.0378 - loc_out_loss: 0.0115 - loc_out_mae: 0.0508 - loss: 0.1665 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0058 - val_cls_out_acc: 0.9085 - val_cls_out_auc: 0.9081 - val_cls_out_loss: 0.0433 - val_loc_out_loss: 0.0125 - val_loc_out_mae: 0.0402 - val_loss: 0.1856 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0048 - learning_rate: 5.0000e-05
# Epoch 5/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - cls_out_acc: 0.8359 - cls_out_auc: 0.9021 - cls_out_loss: 0.0339 - loc_out_loss: 0.0107 - loc_out_mae: 0.0488 - loss: 0.1543 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0053
# Epoch 5: val_cls_out_auc improved from 0.90806 to 0.91745, saving model to /content/best_fracturenet.keras
#
# Epoch 5: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 25s 137ms/step - cls_out_acc: 0.8390 - cls_out_auc: 0.8905 - cls_out_loss: 0.0366 - loc_out_loss: 0.0113 - loc_out_mae: 0.0498 - loss: 0.1626 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0057 - val_cls_out_acc: 0.8987 - val_cls_out_auc: 0.9174 - val_cls_out_loss: 0.0374 - val_loc_out_loss: 0.0116 - val_loc_out_mae: 0.0452 - val_loss: 0.1662 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0048 - learning_rate: 5.0000e-05
# Epoch 6/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.8555 - cls_out_auc: 0.8975 - cls_out_loss: 0.0319 - loc_out_loss: 0.0105 - loc_out_mae: 0.0471 - loss: 0.1473 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0052
# Epoch 6: val_cls_out_auc did not improve from 0.91745
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - cls_out_acc: 0.8548 - cls_out_auc: 0.8940 - cls_out_loss: 0.0358 - loc_out_loss: 0.0113 - loc_out_mae: 0.0491 - loss: 0.1586 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0057 - val_cls_out_acc: 0.9069 - val_cls_out_auc: 0.9125 - val_cls_out_loss: 0.0409 - val_loc_out_loss: 0.0114 - val_loc_out_mae: 0.0402 - val_loss: 0.1763 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 5.0000e-05
# Epoch 7/15
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.8493 - cls_out_auc: 0.9013 - cls_out_loss: 0.0313 - loc_out_loss: 0.0105 - loc_out_mae: 0.0482 - loss: 0.1453 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0054
# Epoch 7: val_cls_out_auc improved from 0.91745 to 0.92365, saving model to /content/best_fracturenet.keras
#
# Epoch 7: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 31s 173ms/step - cls_out_acc: 0.8422 - cls_out_auc: 0.8983 - cls_out_loss: 0.0340 - loc_out_loss: 0.0107 - loc_out_mae: 0.0484 - loss: 0.1530 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0057 - val_cls_out_acc: 0.8971 - val_cls_out_auc: 0.9236 - val_cls_out_loss: 0.0387 - val_loc_out_loss: 0.0112 - val_loc_out_mae: 0.0419 - val_loss: 0.1692 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 5.0000e-05
# Epoch 8/15
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.8534 - cls_out_auc: 0.9106 - cls_out_loss: 0.0294 - loc_out_loss: 0.0096 - loc_out_mae: 0.0456 - loss: 0.1383 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0051
# Epoch 8: val_cls_out_auc did not improve from 0.92365
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - cls_out_acc: 0.8527 - cls_out_auc: 0.9076 - cls_out_loss: 0.0323 - loc_out_loss: 0.0103 - loc_out_mae: 0.0471 - loss: 0.1476 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0056 - val_cls_out_acc: 0.8856 - val_cls_out_auc: 0.9153 - val_cls_out_loss: 0.0397 - val_loc_out_loss: 0.0111 - val_loc_out_mae: 0.0445 - val_loss: 0.1718 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 5.0000e-05
# Epoch 9/15
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - cls_out_acc: 0.8740 - cls_out_auc: 0.9228 - cls_out_loss: 0.0276 - loc_out_loss: 0.0093 - loc_out_mae: 0.0448 - loss: 0.1326 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0053
# Epoch 9: val_cls_out_auc did not improve from 0.92365
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - cls_out_acc: 0.8698 - cls_out_auc: 0.9197 - cls_out_loss: 0.0296 - loc_out_loss: 0.0099 - loc_out_mae: 0.0456 - loss: 0.1389 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0056 - val_cls_out_acc: 0.9052 - val_cls_out_auc: 0.9182 - val_cls_out_loss: 0.0381 - val_loc_out_loss: 0.0108 - val_loc_out_mae: 0.0421 - val_loss: 0.1665 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 2.5000e-05
# Epoch 10/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.8670 - cls_out_auc: 0.9240 - cls_out_loss: 0.0266 - loc_out_loss: 0.0095 - loc_out_mae: 0.0447 - loss: 0.1295 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0052
# Epoch 10: val_cls_out_auc did not improve from 0.92365
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - cls_out_acc: 0.8632 - cls_out_auc: 0.9205 - cls_out_loss: 0.0297 - loc_out_loss: 0.0101 - loc_out_mae: 0.0461 - loss: 0.1389 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0055 - val_cls_out_acc: 0.8791 - val_cls_out_auc: 0.9162 - val_cls_out_loss: 0.0386 - val_loc_out_loss: 0.0108 - val_loc_out_mae: 0.0431 - val_loss: 0.1677 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0049 - learning_rate: 2.5000e-05
# Epoch 11/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - cls_out_acc: 0.8696 - cls_out_auc: 0.9202 - cls_out_loss: 0.0255 - loc_out_loss: 0.0087 - loc_out_mae: 0.0428 - loss: 0.1256 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0051
# Epoch 11: val_cls_out_auc did not improve from 0.92365
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - cls_out_acc: 0.8677 - cls_out_auc: 0.9180 - cls_out_loss: 0.0290 - loc_out_loss: 0.0094 - loc_out_mae: 0.0443 - loss: 0.1361 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0056 - val_cls_out_acc: 0.9020 - val_cls_out_auc: 0.9114 - val_cls_out_loss: 0.0422 - val_loc_out_loss: 0.0107 - val_loc_out_mae: 0.0409 - val_loss: 0.1785 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0048 - learning_rate: 2.5000e-05
# Epoch 12/15
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - cls_out_acc: 0.8634 - cls_out_auc: 0.9228 - cls_out_loss: 0.0267 - loc_out_loss: 0.0089 - loc_out_mae: 0.0429 - loss: 0.1292 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0052
# Epoch 12: val_cls_out_auc did not improve from 0.92365
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - cls_out_acc: 0.8635 - cls_out_auc: 0.9219 - cls_out_loss: 0.0290 - loc_out_loss: 0.0093 - loc_out_mae: 0.0437 - loss: 0.1362 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0055 - val_cls_out_acc: 0.9003 - val_cls_out_auc: 0.9141 - val_cls_out_loss: 0.0408 - val_loc_out_loss: 0.0106 - val_loc_out_mae: 0.0409 - val_loss: 0.1743 - val_seg_out_acc: 0.9991 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0048 - learning_rate: 1.2500e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
#  Saved: /content/03_training_history.png
#
# ============================================================
#  Test Set Evaluation
# ============================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 26s 677ms/step - cls_out_acc: 0.8777 - cls_out_auc: 0.9010 - cls_out_loss: 0.0375 - loc_out_loss: 0.0112 - loc_out_mae: 0.0422 - loss: 0.1639 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0051
#
#  Test Metrics:
#   loss                               : 0.1639
#   compile_metrics                    : 0.0375
#   cls_out_loss                       : 0.0112
#   loc_out_loss                       : 0.0051
#   seg_out_loss                       : 0.8777
#
#   Classification Threshold used: 0.65
#
#  Classification Report:
#                precision    recall  f1-score   support
#
# Non-Fractured       0.89      0.98      0.93       506
#     Fractured       0.85      0.41      0.55       107
#
#      accuracy                           0.88       613
#     macro avg       0.87      0.70      0.74       613
#  weighted avg       0.88      0.88      0.87       613
#
#  AUC-ROC: 0.9010
#  Saved: /content/04_confusion_matrix.png
#  Saved: /content/05_predictions.png
#
# ╔══════════════════════════════════════════════════════════╗
# ║                TRAINING COMPLETE                        ║
# ╠══════════════════════════════════════════════════════════╣
# ║  Original dataset : 4083 images
# ║  Training dataset : 2858 samples (no oversampling)
# ║  Model            : FractureNet (DenseNet121)
# ║  Mixed Precision  : mixed_float16
# ║  L2 Regularization: 0.0001
# ║  CLS Threshold    : 0.65
# ║  Epochs run       : 27 (Phase1=13 + Phase2=13)
# ║  Best Val AUC     : 0.9236  (epoch 22)
# ║  Class Weights    : NonFrac=0.453 | Frac=2.422
# ║
# ║   Outputs:
# ║    /content/best_fracturenet.keras
# ║    /content/01_data_analysis.png
# ║    /content/02_augmentation.png
# ║    /content/03_training_history.png
# ║    /content/04_confusion_matrix.png
# ║    /content/05_predictions.png
# ╚══════════════════════════════════════════════════════════╝
#
# ============================================================
#  Detailed Analysis: Confusion Matrix by Body Part
# ============================================================
#
# ==================== [HAND] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.80      0.95      0.87       136
#     Fractured       0.78      0.44      0.56        57
#
#      accuracy                           0.80       193
#     macro avg       0.79      0.69      0.72       193
#  weighted avg       0.80      0.80      0.78       193
#
#
# ==================== [HIP] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.96      1.00      0.98        26
#     Fractured       0.00      0.00      0.00         1
#
#      accuracy                           0.96        27
#     macro avg       0.48      0.50      0.49        27
#  weighted avg       0.93      0.96      0.94        27
#
#
# ==================== [LEG] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.94      1.00      0.97       287
#     Fractured       0.93      0.41      0.57        32
#
#      accuracy                           0.94       319
#     macro avg       0.93      0.70      0.77       319
#  weighted avg       0.94      0.94      0.93       319
#
#
# ==================== [MIXED] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.81      1.00      0.90        44
#     Fractured       1.00      0.38      0.55        16
#
#      accuracy                           0.83        60
#     macro avg       0.91      0.69      0.72        60
#  weighted avg       0.86      0.83      0.80        60
#
#
# ==================== [SHOULDER] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.93      1.00      0.96        13
#     Fractured       0.00      0.00      0.00         1
#
#      accuracy                           0.93        14
#     macro avg       0.46      0.50      0.48        14
#  weighted avg       0.86      0.93      0.89        14
#  Saved: /content/06_cm_per_body_part.png
