# %%
# ╔══════════════════════════════════════════════════════════════════╗
# ║  BONE FRACTURE DETECTION — FractureNet Multi-Task (TensorFlow)  ║
# ║  Classification + Localization + Segmentation                   ║
# ╚══════════════════════════════════════════════════════════════════╝

# 0. INSTALL
import subprocess
subprocess.run(['pip', 'install', '-q', 'albumentations'], check=False)

# 1. IMPORTS
import os, json, zipfile, random, warnings, glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from tqdm import tqdm
warnings.filterwarnings('ignore')

import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0, EfficientNetB3, EfficientNetB4, ResNet50V2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import seaborn as sns
import albumentations as A

print(f" TensorFlow : {tf.__version__}")
print(f" GPU        : {tf.config.list_physical_devices('GPU')}")

# 2. CONFIGURATION
IMG_SIZE   = (224, 224)
BATCH_SIZE = 16
EPOCHS     = 20
SEED       = 42
LR_PHASE1  = 1e-3
LR_PHASE2  = 5e-5

#  EfficientNetB4
MODEL_CHOICE = 'EfficientNetB4'

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

IMG_H, IMG_W = IMG_SIZE

tf.keras.mixed_precision.set_global_policy('mixed_float16')
print(f" Mixed Precision: {tf.keras.mixed_precision.global_policy().name}")
print(f" Model Choice   : {MODEL_CHOICE}")

def find_zip_file():
    candidates = [
        '/content/archive__32_.zip',
        '/content/drive/MyDrive/archive__32_.zip',
        '/content/drive/My Drive/archive__32_.zip',
    ]
    drive_search = glob.glob('/content/drive/**/*archive*32*.zip', recursive=True)
    drive_search += glob.glob('/content/drive/**/*.zip', recursive=True)
    candidates += drive_search

    for path in candidates:
        if os.path.exists(path):
            print(f"I found the file ZIP: {path}")
            return path
    return None

# ── محاولة Mount Drive أولاً
try:
    from google.colab import drive
    if not os.path.exists('/content/drive'):
        print(" Installation in progress Google Drive...")
        drive.mount('/content/drive')
    else:
        print(" Google DrivePre-assembled")
except Exception as e:
    print(f"  Drive Not available:{e}")

# ── إيجاد الملف
ZIP_PATH = find_zip_file()

# ── لو ما وجد → رفع يدوي
if ZIP_PATH is None:
    print("\n  The file was not found automatically.")
    print("Upload the file now(archive__32_.zip)...")
    try:
        from google.colab import files
        uploaded = files.upload()
        for fname in uploaded:
            dest = f'/content/{fname}'
            with open(dest, 'wb') as f:
                f.write(uploaded[fname])
            ZIP_PATH = dest
            print(f"Uploaded: {dest}")
            break
    except Exception as e:
        raise FileNotFoundError(
            f"The file was not found.\n"
            f"Solution: Manually upload the file to /content/ and press Run again.\n{e}"
        )

print(f"\n path ZIP: {ZIP_PATH}")

# 4. EXTRACT ZIP
#
print("\nExtracting dataset...")

EXTRACT_ROOT = '/content/extracted_dataset'
os.makedirs(EXTRACT_ROOT, exist_ok=True)

with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    z.extractall(EXTRACT_ROOT)

print(" Extraction complete")

DATASET_DIR = None
for root, dirs, _ in os.walk(EXTRACT_ROOT):
    if 'FracAtlas' in dirs:
        DATASET_DIR = os.path.join(root, 'FracAtlas')
        break
    if os.path.basename(root) == 'FracAtlas':
        DATASET_DIR = root
        break

if DATASET_DIR is None:
    for root, dirs, _ in os.walk(EXTRACT_ROOT):
        if 'images' in dirs:
            DATASET_DIR = root
            break

if DATASET_DIR is None:
    raise FileNotFoundError(f" The FracAtlas folder was not found inside the ZIP.\n"
                             f"Extracted volumes: {os.listdir(EXTRACT_ROOT)}")

print(f" Dataset path: {DATASET_DIR}")

FRAC_DIR    = os.path.join(DATASET_DIR, 'images', 'Fractured')
NONFRAC_DIR = os.path.join(DATASET_DIR, 'images', 'Non_fractured')
COCO_PATH   = os.path.join(DATASET_DIR, 'Annotations', 'COCO JSON', 'COCO_fracture_masks.json')

for p in [FRAC_DIR, NONFRAC_DIR, COCO_PATH]:
    if not os.path.exists(p):
        raise FileNotFoundError(f" Missing path: {p}")
print(" All dataset paths verified")

# 5. NORMALIZE EXTENSIONS & IMAGE SIZES
def normalize_images(folder, target_ext='.jpg', target_size=IMG_SIZE):
    converted = 0
    for fname in os.listdir(folder):
        fpath = os.path.join(folder, fname)
        ext = os.path.splitext(fname)[1].lower()
        if ext not in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp']:
            continue
        try:
            img = Image.open(fpath).convert('RGB')
            if ext != target_ext:
                new_path = os.path.splitext(fpath)[0] + target_ext
                img.save(new_path, 'JPEG', quality=95)
                os.remove(fpath)
                converted += 1
        except Exception as e:
            print(f"  Skipping {fname}: {e}")
    print(f"  Converted {converted} files in {os.path.basename(folder)}")

print("\n Normalizing image extensions...")
normalize_images(FRAC_DIR)
normalize_images(NONFRAC_DIR)

# 6. LOAD COCO ANNOTATIONS
with open(COCO_PATH, 'r') as f:
    coco_data = json.load(f)

id_to_img     = {img['id']: img for img in coco_data['images']}
fname_to_anns = {}
for ann in coco_data['annotations']:
    img_info = id_to_img[ann['image_id']]
    fname    = img_info['file_name']
    if fname not in fname_to_anns:
        fname_to_anns[fname] = []
    fname_to_anns[fname].append({
        'bbox'        : ann['bbox'],
        'segmentation': ann['segmentation'],
        'orig_w'      : img_info['width'],
        'orig_h'      : img_info['height'],
    })

print(f"\n Loaded {len(coco_data['annotations'])} annotations "
      f"for {len(fname_to_anns)} fractured images")

# 7. DATA EXPLORATION & VISUALIZATION
VALID_EXTS    = ('.jpg', '.jpeg', '.png')
frac_files    = [f for f in os.listdir(FRAC_DIR)    if f.lower().endswith(VALID_EXTS)]
nonfrac_files = [f for f in os.listdir(NONFRAC_DIR) if f.lower().endswith(VALID_EXTS)]

n_frac    = len(frac_files)
n_nonfrac = len(nonfrac_files)
total     = n_frac + n_nonfrac

print(f"\n{'='*50}")
print(f"  Fractured    : {n_frac:>5}  ({100*n_frac/total:.1f}%)")
print(f"  Non-Fractured: {n_nonfrac:>5}  ({100*n_nonfrac/total:.1f}%)")
print(f"  Total        : {total:>5}")
print(f"  Imbalance    : 1:{n_nonfrac//max(n_frac,1)}")
print(f"{'='*50}")

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle(' FracAtlas — Dataset Analysis', fontsize=16, fontweight='bold', y=0.98)

# Bar chart
ax = axes[0, 0]
bars = ax.bar(['Fractured', 'Non-Fractured'], [n_frac, n_nonfrac],
              color=['#E74C3C', '#2ECC71'], edgecolor='white', linewidth=1.5, width=0.5)
for bar, val in zip(bars, [n_frac, n_nonfrac]):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 40,
            f'{val}\n({100*val/total:.1f}%)', ha='center', fontweight='bold', fontsize=11)
ax.set_title('Class Distribution', fontweight='bold')
ax.set_ylabel('Number of Images')
ax.set_ylim(0, max(n_frac, n_nonfrac) * 1.25)
ax.spines[['top', 'right']].set_visible(False)

# Pie chart
ax = axes[0, 1]
_, _, autotexts = ax.pie(
    [n_frac, n_nonfrac],
    labels=['Fractured', 'Non-Fractured'],
    autopct='%1.1f%%',
    colors=['#E74C3C', '#2ECC71'],
    startangle=140,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2}
)
for at in autotexts:
    at.set_fontweight('bold')
ax.set_title('Class Ratio', fontweight='bold')

# Image width distribution
ax = axes[0, 2]
widths = []
for f in random.sample(frac_files,    min(50, len(frac_files))):
    try: widths.append(Image.open(os.path.join(FRAC_DIR, f)).size[0])
    except: pass
for f in random.sample(nonfrac_files, min(50, len(nonfrac_files))):
    try: widths.append(Image.open(os.path.join(NONFRAC_DIR, f)).size[0])
    except: pass
ax.hist(widths, bins=25, color='steelblue', edgecolor='white', alpha=0.85)
if widths:
    ax.axvline(np.mean(widths), color='red', linestyle='--',
               label=f'Mean: {np.mean(widths):.0f}px')
ax.set_title('Image Width Distribution (sample)', fontweight='bold')
ax.set_xlabel('Width (pixels)')
ax.set_ylabel('Count')
ax.legend()
ax.spines[['top', 'right']].set_visible(False)

# Sample fractured images with bbox
sample_frac = random.sample(frac_files, min(3, len(frac_files)))
for i, fname in enumerate(sample_frac):
    img = np.array(Image.open(os.path.join(FRAC_DIR, fname)).convert('RGB'))
    axes[1, i].imshow(img)
    axes[1, i].set_title('🔴 Fractured', fontweight='bold', color='#E74C3C')
    axes[1, i].axis('off')
    if fname in fname_to_anns:
        ann = fname_to_anns[fname][0]
        x, y, w, h = ann['bbox']
        sx = img.shape[1] / ann['orig_w']
        sy = img.shape[0] / ann['orig_h']
        rect = patches.Rectangle((x*sx, y*sy), w*sx, h*sy,
                                   linewidth=2, edgecolor='yellow', facecolor='none')
        axes[1, i].add_patch(rect)
        axes[1, i].set_title('🔴 Fractured (bbox)', fontweight='bold', color='#E74C3C')

plt.tight_layout()
plt.savefig('/content/01_data_analysis.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/01_data_analysis.png")

# 8. BUILD DATASET LIST
import csv
fname_to_bp = {}
CSV_PATH = os.path.join(DATASET_DIR, 'dataset.csv')
if os.path.exists(CSV_PATH):
    with open(CSV_PATH, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            if row.get('mixed', '0') == '1':
                bp = 'mixed'
            else:
                bps = [b for b in ['hand', 'leg', 'hip', 'shoulder'] if row.get(b, '0') == '1']
                bp = bps[0] if bps else 'unknown'
            fname_to_bp[row['image_id']] = bp
else:
    print("The dataset.csv file was not found; it will be assumed that all parts 'unknown'")

all_data = []
for f in frac_files:
    bp = fname_to_bp.get(f, 'unknown')
    all_data.append({'path': os.path.join(FRAC_DIR, f), 'label': 1, 'fname': f, 'bp': bp, 'combined_label': f"1_{bp}"})
for f in nonfrac_files:
    bp = fname_to_bp.get(f, 'unknown')
    all_data.append({'path': os.path.join(NONFRAC_DIR, f), 'label': 0, 'fname': f, 'bp': bp, 'combined_label': f"0_{bp}"})
random.shuffle(all_data)

# 9. CLASS DISTRIBUTION
frac_data    = [d for d in all_data if d['label'] == 1]
nonfrac_data = [d for d in all_data if d['label'] == 0]
print(f"\n Fractured: {len(frac_data)} | Non-Fractured: {len(nonfrac_data)}")
print(f"   (Sample weights will be used to address imbalances in fractures and body parts)")

# 10. TRAIN / VAL / TEST SPLIT  70 / 15 / 15
labels_all = [d['combined_label'] for d in all_data]
from collections import Counter
counts = Counter(labels_all)
safe_labels_all = [l if counts[l] >= 4 else f"{l.split('_')[0]}_rare" for l in labels_all]

train_data, temp_data = train_test_split(all_data, test_size=0.30,
                                          stratify=safe_labels_all, random_state=SEED)

labels_temp = [d['combined_label'] for d in temp_data]
counts_temp = Counter(labels_temp)
safe_labels_temp = [l if counts_temp[l] >= 2 else f"{l.split('_')[0]}_rare" for l in labels_temp]

val_data, test_data = train_test_split(temp_data, test_size=0.50,
                                        stratify=safe_labels_temp, random_state=SEED)
print(f"\n Train:{len(train_data)} | Val:{len(val_data)} | Test:{len(test_data)}")

# 11. DATA AUGMENTATION
aug_train = A.Compose([
    A.Resize(IMG_H, IMG_W),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomRotate90(p=0.3),
    A.ShiftScaleRotate(shift_limit=0.08, scale_limit=0.12, rotate_limit=15, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.5),
    A.GaussianBlur(blur_limit=(3, 5), p=0.2),
    A.GridDistortion(num_steps=5, distort_limit=0.15, p=0.2),
    A.CLAHE(clip_limit=2.0, p=0.3),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])
aug_val = A.Compose([
    A.Resize(IMG_H, IMG_W),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])

# Augmentation preview
sample_path = os.path.join(FRAC_DIR, frac_files[0])
sample_img  = cv2.cvtColor(cv2.imread(sample_path), cv2.COLOR_BGR2RGB)
fig, axes   = plt.subplots(1, 6, figsize=(20, 4))
fig.suptitle(' Data Augmentation Examples', fontweight='bold', fontsize=14)
axes[0].imshow(cv2.resize(sample_img, IMG_SIZE))
axes[0].set_title('Original', fontweight='bold'); axes[0].axis('off')
for i in range(1, 6):
    aug_img = aug_train(image=sample_img)['image']
    vis = np.clip(aug_img * np.array([0.229,0.224,0.225]) + np.array([0.485,0.456,0.406]), 0, 1)
    axes[i].imshow(vis)
    axes[i].set_title(f'Aug #{i}', fontweight='bold'); axes[i].axis('off')
plt.tight_layout()
plt.savefig('/content/02_augmentation.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/02_augmentation.png")


# 12. HELPER FUNCTIONS
def polygon_to_mask(fname, h, w):
    mask = np.zeros((h, w), dtype=np.float32)
    if fname not in fname_to_anns:
        return mask[..., np.newaxis]
    for ann in fname_to_anns[fname]:
        sx = w / ann['orig_w']
        sy = h / ann['orig_h']
        for seg in ann['segmentation']:
            pts = np.array(seg, dtype=np.float32).reshape(-1, 2)
            pts[:, 0] *= sx
            pts[:, 1] *= sy
            cv2.fillPoly(mask, [pts.astype(np.int32)], 1.0)
    return mask[..., np.newaxis]

def get_bbox(fname):
    if fname not in fname_to_anns:
        return np.array([0., 0., 0., 0.], dtype=np.float32)
    ann = fname_to_anns[fname][0]
    x, y, w, h = ann['bbox']
    ow, oh = ann['orig_w'], ann['orig_h']
    return np.array([(x+w/2)/ow, (y+h/2)/oh, w/ow, h/oh], dtype=np.float32)

# 13. TF DATA PIPELINE (NATIVE & OPTIMIZED)
from sklearn.utils.class_weight import compute_class_weight
train_labels_list = [d['combined_label'] for d in train_data]
unique_labels = np.unique(train_labels_list)
cw = compute_class_weight('balanced', classes=unique_labels, y=train_labels_list)
class_weight_dict = dict(zip(unique_labels, cw))

print("\n⚖️  Sample Weights (لتعويض نقص صور الحوض والكتف):")
for k, v in class_weight_dict.items():
    print(f"   - {k}: {v:.3f}")

def process_data(path, label, fname):
    def _process(path_b, label_b, fname_b):
        path_str = path_b.decode('utf-8')
        fname_str = fname_b.decode('utf-8')

        img = cv2.imread(path_str)
        if img is None:
            img = np.zeros((IMG_H, IMG_W, 3), dtype=np.uint8)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMG_W, IMG_H))

        lbl = np.float32(label_b)
        box = get_bbox(fname_str)
        msk = polygon_to_mask(fname_str, IMG_H, IMG_W)
        return img, lbl, box, msk

    img, lbl, box, msk = tf.numpy_function(
        _process,
        [path, label, fname],
        [tf.uint8, tf.float32, tf.float32, tf.float32]
    )
    img.set_shape([IMG_H, IMG_W, 3])
    lbl.set_shape([])
    box.set_shape([4])
    msk.set_shape([IMG_H, IMG_W, 1])
    return img, lbl, box, msk

def augment_data(img, lbl, box, msk, weight, augment):
    def _aug(img_np):
        if augment:
            tfm = aug_train(image=img_np)
        else:
            tfm = aug_val(image=img_np)
        return tfm['image'].astype(np.float32)

    img_aug = tf.numpy_function(_aug, [img], tf.float32)
    img_aug.set_shape([IMG_H, IMG_W, 3])

    targets = (lbl, box, msk)
    sample_weights = (
        tf.cast(weight, tf.float32),
        tf.constant(1.0, dtype=tf.float32),
        tf.ones((1, 1), dtype=tf.float32)
    )
    return img_aug, targets, sample_weights

def build_ds(data_list, augment=False, shuffle=False):
    paths   = [d['path'] for d in data_list]
    labels  = [d['label'] for d in data_list]
    fnames  = [d['fname'] for d in data_list]
    weights = [class_weight_dict[d['combined_label']] for d in data_list]

    ds = tf.data.Dataset.from_tensor_slices((paths, labels, fnames, weights))

    if shuffle:
        ds = ds.shuffle(len(data_list), seed=SEED)

    ds = ds.map(lambda p, l, f, w: (*process_data(p, l, f), w), num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.cache()

    ds = ds.map(lambda img, lbl, box, msk, w: augment_data(img, lbl, box, msk, w, augment), num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

print("\n Building NATIVE TF datasets...")
train_ds = build_ds(train_data, augment=True,  shuffle=True)
val_ds   = build_ds(val_data,   augment=False, shuffle=False)
test_ds  = build_ds(test_data,  augment=False, shuffle=False)
print("Datasets ready")

# 14. MODEL
def build_fracturenet(freeze=True, model_choice='EfficientNetB0'):
    inputs   = keras.Input(shape=(IMG_H, IMG_W, 3), name='input')

    backbone_map = {
        'EfficientNetB0': EfficientNetB0,
        'EfficientNetB3': EfficientNetB3,
        'EfficientNetB4': EfficientNetB4,
        'ResNet50V2'    : ResNet50V2,
    }
    if model_choice not in backbone_map:
        raise ValueError(f" BackboneNot supported: {model_choice}. "
                         f"Options: {list(backbone_map.keys())}")

    BackboneClass = backbone_map[model_choice]
    backbone = BackboneClass(include_top=False, weights='imagenet', input_tensor=inputs)
    backbone.trainable = not freeze
    feat = backbone.output
    print(f" Backbone: {model_choice} → feature shape: {feat.shape}")

    # Head 1: Classification
    cls = layers.GlobalAveragePooling2D()(feat)
    cls = layers.Dense(512, activation='relu')(cls)
    cls = layers.BatchNormalization()(cls)
    cls = layers.Dropout(0.45)(cls)
    cls = layers.Dense(128, activation='relu')(cls)
    cls = layers.Dropout(0.3)(cls)
    cls_out = layers.Dense(1, activation='sigmoid', dtype='float32', name='cls_out')(cls)

    # Head 2: Localization
    loc = layers.GlobalAveragePooling2D()(feat)
    loc = layers.Dense(256, activation='relu')(loc)
    loc = layers.BatchNormalization()(loc)
    loc = layers.Dropout(0.3)(loc)
    loc = layers.Dense(64, activation='relu')(loc)
    loc_out = layers.Dense(4, activation='sigmoid', dtype='float32', name='loc_out')(loc)

    # Head 3: Segmentation (5× upsample 7→224)
    seg = layers.Conv2DTranspose(512, 3, strides=2, padding='same', activation='relu')(feat)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(64,  3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.BatchNormalization()(seg)
    seg = layers.Conv2DTranspose(32,  3, strides=2, padding='same', activation='relu')(seg)
    seg = layers.Conv2D(16, 3, padding='same', activation='relu')(seg)
    seg_out = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32', name='seg_out')(seg)

    return Model(inputs, [cls_out, loc_out, seg_out], name=f'FractureNet_{model_choice}'), backbone

def compile_model(model, lr):
    model.compile(
        optimizer=keras.optimizers.Adam(lr),
        loss={'cls_out': 'binary_crossentropy',
              'loc_out': 'mse',
              'seg_out': 'binary_crossentropy'},
        loss_weights={'cls_out': 2.0, 'loc_out': 0.5, 'seg_out': 1.0},
        metrics={'cls_out': [keras.metrics.BinaryAccuracy(name='acc'),
                             keras.metrics.AUC(name='auc')],
                 'loc_out': ['mae'],
                 'seg_out': [keras.metrics.BinaryAccuracy(name='acc'),
                             keras.metrics.MeanIoU(num_classes=2, name='iou')]}
    )

print(f"\nBuilding FractureNet with {MODEL_CHOICE}...")
model, backbone = build_fracturenet(freeze=True, model_choice=MODEL_CHOICE)
model.summary(line_length=100)

# 15. CALLBACKS
ckpt_path = '/content/best_fracturenet.keras'

def get_callbacks(patience_es, patience_lr):
    return [
        ModelCheckpoint(ckpt_path, monitor='val_cls_out_auc',
                        mode='max', save_best_only=True, verbose=1),
        EarlyStopping(monitor='val_cls_out_auc', patience=patience_es,
                      restore_best_weights=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', patience=patience_lr,
                          factor=0.5, min_lr=1e-8, verbose=1),
    ]

# 17. PHASE 1: FROZEN BACKBONE — 5 epochs
print("\n" + "="*60)
print(f"🚀 PHASE 1 — {MODEL_CHOICE} frozen | LR=1e-3 | Epochs 1-{EPOCHS//2}")
print("="*60)
compile_model(model, LR_PHASE1)
history1 = model.fit(train_ds, validation_data=val_ds,
                      epochs=EPOCHS//2, callbacks=get_callbacks(4, 2), verbose=1)

# 18. PHASE 2: FINE-TUNE — 5 epochs
freeze_map = {
    'EfficientNetB0': 100,
    'EfficientNetB3': 130,
    'EfficientNetB4': 150,
    'ResNet50V2'    : 100,
}
freeze_n = freeze_map.get(MODEL_CHOICE, 100)

print("\n" + "="*60)
print(f" PHASE 2 — Fine-tune (freeze first {freeze_n} layers) | LR={LR_PHASE2} | Epochs {EPOCHS//2+1}-{EPOCHS}")
print("="*60)
backbone.trainable = True
for layer in backbone.layers[:freeze_n]:
    layer.trainable = False
compile_model(model, LR_PHASE2)
history2 = model.fit(train_ds, validation_data=val_ds,
                      epochs=EPOCHS//2, callbacks=get_callbacks(5, 3), verbose=1)
# 19. PLOT TRAINING HISTORY
def merge_hist(h1, h2):
    return {k: h1.history[k] + h2.history[k] for k in h1.history}

H          = merge_hist(history1, history2)
n_ep       = len(H['loss'])
ep_range   = range(1, n_ep + 1)
phase_line = EPOCHS // 2

metrics_plot = [
    ('loss',          'val_loss',          'Total Loss',              '#E74C3C'),
    ('cls_out_acc',   'val_cls_out_acc',   'Classification Accuracy', '#3498DB'),
    ('cls_out_auc',   'val_cls_out_auc',   'Classification AUC',      '#9B59B6'),
    ('loc_out_mae',   'val_loc_out_mae',   'Localization MAE',         '#F39C12'),
    ('seg_out_acc',   'val_seg_out_acc',   'Segmentation Accuracy',   '#27AE60'),
    ('seg_out_iou',   'val_seg_out_iou',   'Segmentation IoU',         '#1ABC9C'),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle(f' FractureNet ({MODEL_CHOICE}) — Training History ({n_ep} Epochs)',
              fontsize=16, fontweight='bold')
axes = axes.flatten()

for idx, (tk, vk, title, color) in enumerate(metrics_plot):
    ax = axes[idx]
    if tk not in H:
        ax.set_visible(False); continue
    ax.plot(ep_range, H[tk], label='Train', color=color, lw=2.5, marker='o', ms=3)
    ax.plot(ep_range, H[vk], label='Val',   color=color, lw=2.5,
            linestyle='--', marker='s', ms=3, alpha=0.7)
    ax.axvline(phase_line + 0.5, color='gray', ls=':', lw=1.5, label='Phase 1→2')
    ax.set_title(title, fontweight='bold', fontsize=12)
    ax.set_xlabel('Epoch')
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.3)
    ax.spines[['top', 'right']].set_visible(False)

plt.tight_layout()
plt.savefig('/content/03_training_history.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/03_training_history.png")

# 19. EVALUATE ON TEST SET
print("\n" + "="*60)
print("Test Set Evaluation")
print("="*60)
test_results = model.evaluate(test_ds, verbose=1)
print("\n Test Metrics:")
for name, val in zip(model.metrics_names, test_results):
    print(f"  {name:<35}: {val:.4f}")

y_true, y_prob, y_pred = [], [], []
for img_b, lbl_b, _ in test_ds:
    cp, _, _ = model.predict(img_b, verbose=0)
    y_true.extend(lbl_b[0].numpy().astype(int).tolist())
    y_prob.extend(cp.flatten().tolist())
    y_pred.extend((cp.flatten() > 0.5).astype(int).tolist())

print("\n Classification Report:")
print(classification_report(y_true, y_pred,
                             target_names=['Non-Fractured', 'Fractured']))
try:
    print(f"AUC-ROC: {roc_auc_score(y_true, y_prob):.4f}")
except Exception as e:
    print(f"AUC: {e}")

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots(figsize=(7, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Fractured', 'Fractured'],
            yticklabels=['Non-Fractured', 'Fractured'],
            ax=ax, linewidths=0.5, cbar_kws={'shrink': 0.8})
ax.set_title('Confusion Matrix — Test Set', fontweight='bold', fontsize=14, pad=15)
ax.set_xlabel('Predicted'); ax.set_ylabel('True')
plt.tight_layout()
plt.savefig('/content/04_confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/04_confusion_matrix.png")

# 20. PREDICTION VISUALIZATION
def denorm(img):
    return np.clip(img * np.array([0.229,0.224,0.225]) + np.array([0.485,0.456,0.406]), 0, 1)

for img_b, lbl_b, _ in test_ds.take(1):
    cp, lp, sp = model.predict(img_b, verbose=0)
    break

cls_true = lbl_b[0].numpy()
loc_true = lbl_b[1].numpy()
seg_true = lbl_b[2].numpy()
n_show   = min(5, img_b.shape[0])

fig, axes = plt.subplots(n_show, 5, figsize=(22, 4.5 * n_show))
fig.suptitle('🔬 FractureNet — Classification | Localization | Segmentation',
              fontsize=13, fontweight='bold', y=1.01)

for col, title in enumerate(['Original', 'GT BBox', 'Pred BBox', 'GT Mask', 'Pred Mask']):
    axes[0, col].set_title(title, fontweight='bold', fontsize=11)

for i in range(n_show):
    vis          = denorm(img_b[i].numpy())
    is_true_frac = cls_true[i] > 0.5
    is_pred_frac = cp[i][0]   > 0.5
    prob         = float(cp[i][0])

    # Col 0: Original
    axes[i, 0].imshow(vis)
    axes[i, 0].set_title('🔴 Fractured' if is_true_frac else '🟢 Normal', fontsize=9)
    axes[i, 0].axis('off')

    # Col 1: GT bbox
    axes[i, 1].imshow(vis)
    if is_true_frac and loc_true[i].sum() > 0:
        xc, yc, bw, bh = loc_true[i]
        rect = patches.Rectangle(((xc-bw/2)*IMG_W, (yc-bh/2)*IMG_H),
                                   bw*IMG_W, bh*IMG_H, lw=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect)
    axes[i, 1].axis('off')

    # Col 2: Pred bbox
    axes[i, 2].imshow(vis)
    if is_pred_frac:
        xc, yc, bw, bh = lp[i]
        rect = patches.Rectangle(((xc-bw/2)*IMG_W, (yc-bh/2)*IMG_H),
                                   bw*IMG_W, bh*IMG_H, lw=2, edgecolor='yellow', facecolor='none')
        axes[i, 2].add_patch(rect)
    axes[i, 2].set_title(f"{'🔴' if is_pred_frac else '🟢'} {prob:.1%}", fontsize=9)
    axes[i, 2].axis('off')

    # Col 3: GT mask
    axes[i, 3].imshow(vis)
    if seg_true[i].sum() > 0:
        axes[i, 3].imshow(seg_true[i,:,:,0], alpha=0.55, cmap='Reds', vmin=0, vmax=1)
    axes[i, 3].axis('off')

    # Col 4: Pred mask
    axes[i, 4].imshow(vis)
    pred_mask = sp[i,:,:,0]
    if pred_mask.max() > 0.1:
        axes[i, 4].imshow(pred_mask > 0.5, alpha=0.55, cmap='hot', vmin=0, vmax=1)
    axes[i, 4].axis('off')

plt.tight_layout()
plt.savefig('/content/05_predictions.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/05_predictions.png")

# 21. FINAL SUMMARY

best_auc = max(H.get('val_cls_out_auc', [0]))
best_ep  = np.argmax(H.get('val_cls_out_auc', [0])) + 1

print("\n╔" + "═"*58 + "╗")
print("║                TRAINING COMPLETE                        ║")
print("╠" + "═"*58 + "╣")
print(f"║  Original dataset : {total} images")
print(f"║  Training dataset : {len(train_data)} samples (no oversampling)")
print(f"║  Model            : FractureNet ({MODEL_CHOICE})")
print(f"║  Mixed Precision  : {tf.keras.mixed_precision.global_policy().name}")
print(f"║  Epochs run       : {n_ep} (Phase1={n_ep//2} + Phase2={n_ep//2})")
print(f"║  Best Val AUC     : {best_auc:.4f}  (epoch {best_ep})")
print(f"║  Class Weights    : NonFrac={cw[0]:.3f} | Frac={cw[1]:.3f}")
print("║")
print("║   Outputs:")
print("║    /content/best_fracturenet.keras")
print("║    /content/01_data_analysis.png")
print("║    /content/02_augmentation.png")
print("║    /content/03_training_history.png")
print("║    /content/04_confusion_matrix.png")
print("║    /content/05_predictions.png")
print("╚" + "═"*58 + "╝")

# 22. CONFUSION MATRIX PER BODY PART
print("\n" + "="*60)
print(" Detailed Analysis: Confusion Matrix by Body Part")
print("="*60)

test_bps = [d['bp'] for d in test_data]
unique_bps = sorted(list(set(test_bps)))

fig, axes = plt.subplots(1, len(unique_bps), figsize=(4.5 * len(unique_bps), 4.5))
if len(unique_bps) == 1:
    axes = [axes]
fig.suptitle('🔬 Confusion Matrices per Body Part', fontsize=16, fontweight='bold', y=1.05)

for idx, bp in enumerate(unique_bps):
    bp_indices = [i for i, part in enumerate(test_bps) if part == bp]
    if len(bp_indices) == 0: continue

    bp_y_true = [y_true[i] for i in bp_indices]
    bp_y_pred = [y_pred[i] for i in bp_indices]

    print(f"\n{'='*20} [{bp.upper()}] {'='*20}")
    print(classification_report(bp_y_true, bp_y_pred, target_names=['Non-Fractured', 'Fractured'], zero_division=0))

    cm_bp = confusion_matrix(bp_y_true, bp_y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm_bp.ravel()

    acc = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0

    sns.heatmap(cm_bp, annot=True, fmt='d', cmap='Oranges',
                xticklabels=['Non-Frac', 'Frac'],
                yticklabels=['Non-Frac', 'Frac'],
                ax=axes[idx], linewidths=0.5, cbar=False)

    title_text = f'{bp.upper()} (n={len(bp_indices)})\nAcc: {acc:.1%} | Recall: {recall:.1%}'
    axes[idx].set_title(title_text, fontweight='bold', pad=10)
    axes[idx].set_xlabel('Predicted')
    if idx == 0:
        axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig('/content/06_cm_per_body_part.png', dpi=150, bbox_inches='tight')
plt.show()
print(" Saved: /content/06_cm_per_body_part.png")
# Out:
# ✅ TensorFlow : 2.20.0
# ✅ GPU        : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ⚡ Mixed Precision: mixed_float16
# 🧠 Model Choice   : EfficientNetB4
# ✅ Google Drive مُركَّب مسبقاً
# ✅ وجدت ملف الـ ZIP: /content/drive/MyDrive/archive (31).zip
#
# 📁 مسار الـ ZIP: /content/drive/MyDrive/archive (31).zip
#
# 📦 Extracting dataset...
# ✅ Extraction complete
# 📁 Dataset path: /content/extracted_dataset/FracAtlas
# ✅ All dataset paths verified
#
# 🔧 Normalizing image extensions...
#   Converted 0 files in Fractured
# ⚠️  Skipping IMG0004169.jpg: image file is truncated (14 bytes not processed)
# ⚠️  Skipping IMG0004129.jpg: image file is truncated (6 bytes not processed)
# ⚠️  Skipping IMG0004122.jpg: image file is truncated (26 bytes not processed)
# ⚠️  Skipping IMG0004228.jpg: image file is truncated (17 bytes not processed)
# ⚠️  Skipping IMG0004298.jpg: image file is truncated (19 bytes not processed)
# ⚠️  Skipping IMG0004100.jpg: image file is truncated (15 bytes not processed)
# ⚠️  Skipping IMG0004173.jpg: image file is truncated (0 bytes not processed)
# ⚠️  Skipping IMG0004279.jpg: image file is truncated (5 bytes not processed)
# ⚠️  Skipping IMG0004092.jpg: image file is truncated (3 bytes not processed)
# ⚠️  Skipping IMG0004291.jpg: image file is truncated (13 bytes not processed)
# ⚠️  Skipping IMG0004347.jpg: image file is truncated (40 bytes not processed)
# ⚠️  Skipping IMG0004170.jpg: image file is truncated (11 bytes not processed)
# ⚠️  Skipping IMG0004297.jpg: image file is truncated (5 bytes not processed)
# ⚠️  Skipping IMG0004036.jpg: image file is truncated (14 bytes not processed)
# ⚠️  Skipping IMG0004159.jpg: image file is truncated (8 bytes not processed)
# ⚠️  Skipping IMG0004256.jpg: image file is truncated (66 bytes not processed)
# ⚠️  Skipping IMG0004288.jpg: image file is truncated (1 bytes not processed)
# ⚠️  Skipping IMG0004194.jpg: image file is truncated (10 bytes not processed)
# ⚠️  Skipping IMG0004227.jpg: image file is truncated (30 bytes not processed)
# ⚠️  Skipping IMG0004073.jpg: image file is truncated (3 bytes not processed)
# ⚠️  Skipping IMG0004148.jpg: image file is truncated (14 bytes not processed)
# ⚠️  Skipping IMG0004130.jpg: image file is truncated (8 bytes not processed)
# ⚠️  Skipping IMG0004098.jpg: image file is truncated (17 bytes not processed)
# ⚠️  Skipping IMG0004120.jpg: image file is truncated (8 bytes not processed)
# ⚠️  Skipping IMG0004084.jpg: image file is truncated (5 bytes not processed)
# ⚠️  Skipping IMG0004174.jpg: image file is truncated (4 bytes not processed)
# ⚠️  Skipping IMG0004155.jpg: image file is truncated (18 bytes not processed)
# ⚠️  Skipping IMG0004076.jpg: image file is truncated (0 bytes not processed)
# ⚠️  Skipping IMG0004285.jpg: image file is truncated (9 bytes not processed)
# ⚠️  Skipping IMG0004189.jpg: image file is truncated (16 bytes not processed)
# ⚠️  Skipping IMG0004149.jpg: image file is truncated (33 bytes not processed)
# ⚠️  Skipping IMG0004145.jpg: image file is truncated (10 bytes not processed)
# ⚠️  Skipping IMG0004278.jpg: image file is truncated (29 bytes not processed)
# ⚠️  Skipping IMG0004252.jpg: image file is truncated (67 bytes not processed)
# ⚠️  Skipping IMG0004143.jpg: image file is truncated (10 bytes not processed)
# ⚠️  Skipping IMG0004177.jpg: image file is truncated (34 bytes not processed)
# ⚠️  Skipping IMG0004028.jpg: image file is truncated (20 bytes not processed)
# ⚠️  Skipping IMG0004290.jpg: image file is truncated (54 bytes not processed)
# ⚠️  Skipping IMG0004275.jpg: image file is truncated (24 bytes not processed)
# ⚠️  Skipping IMG0004263.jpg: image file is truncated (24 bytes not processed)
# ⚠️  Skipping IMG0004142.jpg: image file is truncated (32 bytes not processed)
# ⚠️  Skipping IMG0004121.jpg: image file is truncated (40 bytes not processed)
# ⚠️  Skipping IMG0004258.jpg: image file is truncated (0 bytes not processed)
# ⚠️  Skipping IMG0004123.jpg: image file is truncated (17 bytes not processed)
# ⚠️  Skipping IMG0004308.jpg: image file is truncated (40 bytes not processed)
# ⚠️  Skipping IMG0004154.jpg: image file is truncated (22 bytes not processed)
# ⚠️  Skipping IMG0004134.jpg: image file is truncated (1 bytes not processed)
# ⚠️  Skipping IMG0004029.jpg: image file is truncated (22 bytes not processed)
# ⚠️  Skipping IMG0004079.jpg: image file is truncated (24 bytes not processed)
# ⚠️  Skipping IMG0004304.jpg: image file is truncated (22 bytes not processed)
# ⚠️  Skipping IMG0004070.jpg: image file is truncated (41 bytes not processed)
# ⚠️  Skipping IMG0004109.jpg: image file is truncated (5 bytes not processed)
# ⚠️  Skipping IMG0004119.jpg: image file is truncated (6 bytes not processed)
# ⚠️  Skipping IMG0004255.jpg: image file is truncated (20 bytes not processed)
# ⚠️  Skipping IMG0004273.jpg: image file is truncated (8 bytes not processed)
# ⚠️  Skipping IMG0004251.jpg: image file is truncated (19 bytes not processed)
# ⚠️  Skipping IMG0004286.jpg: image file is truncated (46 bytes not processed)
# ⚠️  Skipping IMG0004226.jpg: image file is truncated (23 bytes not processed)
# ⚠️  Skipping IMG0004259.jpg: image file is truncated (7 bytes not processed)
#   Converted 0 files in Non_fractured
#
# ✅ Loaded 922 annotations for 717 fractured images
#
# ==================================================
#   Fractured    :   717  (17.6%)
#   Non-Fractured:  3366  (82.4%)
#   Total        :  4083
#   Imbalance    : 1:4
# ==================================================
# 💾 Saved: /content/01_data_analysis.png
#
# ⚖️  Fractured: 717 | Non-Fractured: 3366
#    (سيتم استخدام Sample Weights لمعالجة عدم التوازن للكسور وأجزاء الجسم)
#
# 📂 Train:2858 | Val:612 | Test:613
# 💾 Saved: /content/02_augmentation.png
#
# ⚖️  Sample Weights (لتعويض نقص صور الحوض والكتف):
#    - 0_hand: 0.453
#    - 0_hip: 2.422
#    - 0_leg: 0.214
#    - 0_mixed: 1.394
#    - 0_shoulder: 4.466
#    - 1_hand: 1.078
#    - 1_hip: 40.829
#    - 1_leg: 1.918
#    - 1_mixed: 3.862
#    - 1_shoulder: 40.829
#
# 🔄 Building NATIVE TF datasets...
# ✅ Datasets ready
#
# 🏗️  Building FractureNet with EfficientNetB4...
# 🧠 Backbone: EfficientNetB4 → feature shape: (None, 7, 7, 1792)
# Model: "FractureNet_EfficientNetB4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)          │ (None, 224, 224, 3)     │              0 │ -                       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ rescaling (Rescaling)       │ (None, 224, 224, 3)     │              0 │ input[0][0]             │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ normalization               │ (None, 224, 224, 3)     │              7 │ rescaling[0][0]         │
# │ (Normalization)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ rescaling_1 (Rescaling)     │ (None, 224, 224, 3)     │              0 │ normalization[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_conv_pad               │ (None, 225, 225, 3)     │              0 │ rescaling_1[0][0]       │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_conv (Conv2D)          │ (None, 112, 112, 48)    │          1,296 │ stem_conv_pad[0][0]     │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_bn                     │ (None, 112, 112, 48)    │            192 │ stem_conv[0][0]         │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ stem_activation             │ (None, 112, 112, 48)    │              0 │ stem_bn[0][0]           │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_dwconv              │ (None, 112, 112, 48)    │            432 │ stem_activation[0][0]   │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_bn                  │ (None, 112, 112, 48)    │            192 │ block1a_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_activation          │ (None, 112, 112, 48)    │              0 │ block1a_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_se_squeeze          │ (None, 48)              │              0 │ block1a_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_se_reshape          │ (None, 1, 1, 48)        │              0 │ block1a_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_se_reduce (Conv2D)  │ (None, 1, 1, 12)        │            588 │ block1a_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_se_expand (Conv2D)  │ (None, 1, 1, 48)        │            624 │ block1a_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_se_excite           │ (None, 112, 112, 48)    │              0 │ block1a_activation[0][… │
# │ (Multiply)                  │                         │                │ block1a_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_project_conv        │ (None, 112, 112, 24)    │          1,152 │ block1a_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1a_project_bn          │ (None, 112, 112, 24)    │             96 │ block1a_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_dwconv              │ (None, 112, 112, 24)    │            216 │ block1a_project_bn[0][… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_bn                  │ (None, 112, 112, 24)    │             96 │ block1b_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_activation          │ (None, 112, 112, 24)    │              0 │ block1b_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_se_squeeze          │ (None, 24)              │              0 │ block1b_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_se_reshape          │ (None, 1, 1, 24)        │              0 │ block1b_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_se_reduce (Conv2D)  │ (None, 1, 1, 6)         │            150 │ block1b_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_se_expand (Conv2D)  │ (None, 1, 1, 24)        │            168 │ block1b_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_se_excite           │ (None, 112, 112, 24)    │              0 │ block1b_activation[0][… │
# │ (Multiply)                  │                         │                │ block1b_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_project_conv        │ (None, 112, 112, 24)    │            576 │ block1b_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_project_bn          │ (None, 112, 112, 24)    │             96 │ block1b_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_drop (Dropout)      │ (None, 112, 112, 24)    │              0 │ block1b_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block1b_add (Add)           │ (None, 112, 112, 24)    │              0 │ block1b_drop[0][0],     │
# │                             │                         │                │ block1a_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_expand_conv         │ (None, 112, 112, 144)   │          3,456 │ block1b_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_expand_bn           │ (None, 112, 112, 144)   │            576 │ block2a_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_expand_activation   │ (None, 112, 112, 144)   │              0 │ block2a_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_dwconv_pad          │ (None, 113, 113, 144)   │              0 │ block2a_expand_activat… │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_dwconv              │ (None, 56, 56, 144)     │          1,296 │ block2a_dwconv_pad[0][… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_bn                  │ (None, 56, 56, 144)     │            576 │ block2a_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_activation          │ (None, 56, 56, 144)     │              0 │ block2a_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_se_squeeze          │ (None, 144)             │              0 │ block2a_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_se_reshape          │ (None, 1, 1, 144)       │              0 │ block2a_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_se_reduce (Conv2D)  │ (None, 1, 1, 6)         │            870 │ block2a_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_se_expand (Conv2D)  │ (None, 1, 1, 144)       │          1,008 │ block2a_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_se_excite           │ (None, 56, 56, 144)     │              0 │ block2a_activation[0][… │
# │ (Multiply)                  │                         │                │ block2a_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_project_conv        │ (None, 56, 56, 32)      │          4,608 │ block2a_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2a_project_bn          │ (None, 56, 56, 32)      │            128 │ block2a_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_expand_conv         │ (None, 56, 56, 192)     │          6,144 │ block2a_project_bn[0][… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_expand_bn           │ (None, 56, 56, 192)     │            768 │ block2b_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_expand_activation   │ (None, 56, 56, 192)     │              0 │ block2b_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_dwconv              │ (None, 56, 56, 192)     │          1,728 │ block2b_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_bn                  │ (None, 56, 56, 192)     │            768 │ block2b_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_activation          │ (None, 56, 56, 192)     │              0 │ block2b_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_se_squeeze          │ (None, 192)             │              0 │ block2b_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_se_reshape          │ (None, 1, 1, 192)       │              0 │ block2b_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_se_reduce (Conv2D)  │ (None, 1, 1, 8)         │          1,544 │ block2b_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_se_expand (Conv2D)  │ (None, 1, 1, 192)       │          1,728 │ block2b_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_se_excite           │ (None, 56, 56, 192)     │              0 │ block2b_activation[0][… │
# │ (Multiply)                  │                         │                │ block2b_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_project_conv        │ (None, 56, 56, 32)      │          6,144 │ block2b_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_project_bn          │ (None, 56, 56, 32)      │            128 │ block2b_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_drop (Dropout)      │ (None, 56, 56, 32)      │              0 │ block2b_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2b_add (Add)           │ (None, 56, 56, 32)      │              0 │ block2b_drop[0][0],     │
# │                             │                         │                │ block2a_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_expand_conv         │ (None, 56, 56, 192)     │          6,144 │ block2b_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_expand_bn           │ (None, 56, 56, 192)     │            768 │ block2c_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_expand_activation   │ (None, 56, 56, 192)     │              0 │ block2c_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_dwconv              │ (None, 56, 56, 192)     │          1,728 │ block2c_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_bn                  │ (None, 56, 56, 192)     │            768 │ block2c_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_activation          │ (None, 56, 56, 192)     │              0 │ block2c_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_se_squeeze          │ (None, 192)             │              0 │ block2c_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_se_reshape          │ (None, 1, 1, 192)       │              0 │ block2c_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_se_reduce (Conv2D)  │ (None, 1, 1, 8)         │          1,544 │ block2c_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_se_expand (Conv2D)  │ (None, 1, 1, 192)       │          1,728 │ block2c_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_se_excite           │ (None, 56, 56, 192)     │              0 │ block2c_activation[0][… │
# │ (Multiply)                  │                         │                │ block2c_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_project_conv        │ (None, 56, 56, 32)      │          6,144 │ block2c_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_project_bn          │ (None, 56, 56, 32)      │            128 │ block2c_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_drop (Dropout)      │ (None, 56, 56, 32)      │              0 │ block2c_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2c_add (Add)           │ (None, 56, 56, 32)      │              0 │ block2c_drop[0][0],     │
# │                             │                         │                │ block2b_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_expand_conv         │ (None, 56, 56, 192)     │          6,144 │ block2c_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_expand_bn           │ (None, 56, 56, 192)     │            768 │ block2d_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_expand_activation   │ (None, 56, 56, 192)     │              0 │ block2d_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_dwconv              │ (None, 56, 56, 192)     │          1,728 │ block2d_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_bn                  │ (None, 56, 56, 192)     │            768 │ block2d_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_activation          │ (None, 56, 56, 192)     │              0 │ block2d_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_se_squeeze          │ (None, 192)             │              0 │ block2d_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_se_reshape          │ (None, 1, 1, 192)       │              0 │ block2d_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_se_reduce (Conv2D)  │ (None, 1, 1, 8)         │          1,544 │ block2d_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_se_expand (Conv2D)  │ (None, 1, 1, 192)       │          1,728 │ block2d_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_se_excite           │ (None, 56, 56, 192)     │              0 │ block2d_activation[0][… │
# │ (Multiply)                  │                         │                │ block2d_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_project_conv        │ (None, 56, 56, 32)      │          6,144 │ block2d_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_project_bn          │ (None, 56, 56, 32)      │            128 │ block2d_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_drop (Dropout)      │ (None, 56, 56, 32)      │              0 │ block2d_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block2d_add (Add)           │ (None, 56, 56, 32)      │              0 │ block2d_drop[0][0],     │
# │                             │                         │                │ block2c_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_expand_conv         │ (None, 56, 56, 192)     │          6,144 │ block2d_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_expand_bn           │ (None, 56, 56, 192)     │            768 │ block3a_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_expand_activation   │ (None, 56, 56, 192)     │              0 │ block3a_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_dwconv_pad          │ (None, 59, 59, 192)     │              0 │ block3a_expand_activat… │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_dwconv              │ (None, 28, 28, 192)     │          4,800 │ block3a_dwconv_pad[0][… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_bn                  │ (None, 28, 28, 192)     │            768 │ block3a_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_activation          │ (None, 28, 28, 192)     │              0 │ block3a_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_se_squeeze          │ (None, 192)             │              0 │ block3a_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_se_reshape          │ (None, 1, 1, 192)       │              0 │ block3a_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_se_reduce (Conv2D)  │ (None, 1, 1, 8)         │          1,544 │ block3a_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_se_expand (Conv2D)  │ (None, 1, 1, 192)       │          1,728 │ block3a_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_se_excite           │ (None, 28, 28, 192)     │              0 │ block3a_activation[0][… │
# │ (Multiply)                  │                         │                │ block3a_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_project_conv        │ (None, 28, 28, 56)      │         10,752 │ block3a_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3a_project_bn          │ (None, 28, 28, 56)      │            224 │ block3a_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_expand_conv         │ (None, 28, 28, 336)     │         18,816 │ block3a_project_bn[0][… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_expand_bn           │ (None, 28, 28, 336)     │          1,344 │ block3b_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_expand_activation   │ (None, 28, 28, 336)     │              0 │ block3b_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_dwconv              │ (None, 28, 28, 336)     │          8,400 │ block3b_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_bn                  │ (None, 28, 28, 336)     │          1,344 │ block3b_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_activation          │ (None, 28, 28, 336)     │              0 │ block3b_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_se_squeeze          │ (None, 336)             │              0 │ block3b_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_se_reshape          │ (None, 1, 1, 336)       │              0 │ block3b_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_se_reduce (Conv2D)  │ (None, 1, 1, 14)        │          4,718 │ block3b_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_se_expand (Conv2D)  │ (None, 1, 1, 336)       │          5,040 │ block3b_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_se_excite           │ (None, 28, 28, 336)     │              0 │ block3b_activation[0][… │
# │ (Multiply)                  │                         │                │ block3b_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_project_conv        │ (None, 28, 28, 56)      │         18,816 │ block3b_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_project_bn          │ (None, 28, 28, 56)      │            224 │ block3b_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_drop (Dropout)      │ (None, 28, 28, 56)      │              0 │ block3b_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3b_add (Add)           │ (None, 28, 28, 56)      │              0 │ block3b_drop[0][0],     │
# │                             │                         │                │ block3a_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_expand_conv         │ (None, 28, 28, 336)     │         18,816 │ block3b_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_expand_bn           │ (None, 28, 28, 336)     │          1,344 │ block3c_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_expand_activation   │ (None, 28, 28, 336)     │              0 │ block3c_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_dwconv              │ (None, 28, 28, 336)     │          8,400 │ block3c_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_bn                  │ (None, 28, 28, 336)     │          1,344 │ block3c_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_activation          │ (None, 28, 28, 336)     │              0 │ block3c_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_se_squeeze          │ (None, 336)             │              0 │ block3c_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_se_reshape          │ (None, 1, 1, 336)       │              0 │ block3c_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_se_reduce (Conv2D)  │ (None, 1, 1, 14)        │          4,718 │ block3c_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_se_expand (Conv2D)  │ (None, 1, 1, 336)       │          5,040 │ block3c_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_se_excite           │ (None, 28, 28, 336)     │              0 │ block3c_activation[0][… │
# │ (Multiply)                  │                         │                │ block3c_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_project_conv        │ (None, 28, 28, 56)      │         18,816 │ block3c_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_project_bn          │ (None, 28, 28, 56)      │            224 │ block3c_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_drop (Dropout)      │ (None, 28, 28, 56)      │              0 │ block3c_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3c_add (Add)           │ (None, 28, 28, 56)      │              0 │ block3c_drop[0][0],     │
# │                             │                         │                │ block3b_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_expand_conv         │ (None, 28, 28, 336)     │         18,816 │ block3c_add[0][0]       │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_expand_bn           │ (None, 28, 28, 336)     │          1,344 │ block3d_expand_conv[0]… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_expand_activation   │ (None, 28, 28, 336)     │              0 │ block3d_expand_bn[0][0] │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_dwconv              │ (None, 28, 28, 336)     │          8,400 │ block3d_expand_activat… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_bn                  │ (None, 28, 28, 336)     │          1,344 │ block3d_dwconv[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_activation          │ (None, 28, 28, 336)     │              0 │ block3d_bn[0][0]        │
# │ (Activation)                │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_se_squeeze          │ (None, 336)             │              0 │ block3d_activation[0][… │
# │ (GlobalAveragePooling2D)    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_se_reshape          │ (None, 1, 1, 336)       │              0 │ block3d_se_squeeze[0][… │
# │ (Reshape)                   │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_se_reduce (Conv2D)  │ (None, 1, 1, 14)        │          4,718 │ block3d_se_reshape[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_se_expand (Conv2D)  │ (None, 1, 1, 336)       │          5,040 │ block3d_se_reduce[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_se_excite           │ (None, 28, 28, 336)     │              0 │ block3d_activation[0][… │
# │ (Multiply)                  │                         │                │ block3d_se_expand[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_project_conv        │ (None, 28, 28, 56)      │         18,816 │ block3d_se_excite[0][0] │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_project_bn          │ (None, 28, 28, 56)      │            224 │ block3d_project_conv[0… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_drop (Dropout)      │ (None, 28, 28, 56)      │              0 │ block3d_project_bn[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block3d_add (Add)           │ (None, 28, 28, 56)      │              0 │ block3d_drop[0][0],     │
# │                             │                         │                │ block3c_add[0][0]       │
# ...
# Epoch 8/10
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - cls_out_acc: 0.5555 - cls_out_auc: 0.6120 - cls_out_loss: 0.6617 - loc_out_loss: 0.0160 - loc_out_mae: 0.0642 - loss: 1.3375 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0061
# Epoch 8: val_cls_out_auc did not improve from 0.61318
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 86ms/step - cls_out_acc: 0.5609 - cls_out_auc: 0.6173 - cls_out_loss: 0.6880 - loc_out_loss: 0.0171 - loc_out_mae: 0.0665 - loss: 1.3759 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.3513 - val_cls_out_auc: 0.6051 - val_cls_out_loss: 0.6996 - val_loc_out_loss: 0.0153 - val_loc_out_mae: 0.0685 - val_loss: 1.4328 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0068 - learning_rate: 2.5000e-04
# Epoch 9/10
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - cls_out_acc: 0.5348 - cls_out_auc: 0.5874 - cls_out_loss: 0.7024 - loc_out_loss: 0.0160 - loc_out_mae: 0.0642 - loss: 1.4188 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0060
# Epoch 9: val_cls_out_auc did not improve from 0.61318
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - cls_out_acc: 0.5535 - cls_out_auc: 0.6186 - cls_out_loss: 0.7132 - loc_out_loss: 0.0170 - loc_out_mae: 0.0662 - loss: 1.4353 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.7565 - val_cls_out_auc: 0.6089 - val_cls_out_loss: 0.6813 - val_loc_out_loss: 0.0153 - val_loc_out_mae: 0.0621 - val_loss: 1.3976 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0067 - learning_rate: 2.5000e-04
# Epoch 10/10
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - cls_out_acc: 0.5402 - cls_out_auc: 0.5916 - cls_out_loss: 0.7135 - loc_out_loss: 0.0154 - loc_out_mae: 0.0633 - loss: 1.4406 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0060
# Epoch 10: val_cls_out_auc did not improve from 0.61318
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 22s 95ms/step - cls_out_acc: 0.5458 - cls_out_auc: 0.6068 - cls_out_loss: 0.7291 - loc_out_loss: 0.0165 - loc_out_mae: 0.0661 - loss: 1.4603 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.3905 - val_cls_out_auc: 0.5702 - val_cls_out_loss: 0.6898 - val_loc_out_loss: 0.0157 - val_loc_out_mae: 0.0604 - val_loss: 1.4132 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0067 - learning_rate: 2.5000e-04
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ============================================================
# 🔓 PHASE 2 — Fine-tune (freeze first 150 layers) | LR=5e-05 | Epochs 11-20
# ============================================================
# Epoch 1/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - cls_out_acc: 0.4766 - cls_out_auc: 0.5144 - cls_out_loss: 0.9776 - loc_out_loss: 0.0464 - loc_out_mae: 0.1309 - loss: 1.9855 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0073
# Epoch 1: val_cls_out_auc improved from None to 0.59315, saving model to /content/best_fracturenet.keras
#
# Epoch 1: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 629s 2s/step - cls_out_acc: 0.4892 - cls_out_auc: 0.5273 - cls_out_loss: 0.9959 - loc_out_loss: 0.0376 - loc_out_mae: 0.1144 - loss: 1.9881 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0074 - val_cls_out_acc: 0.7761 - val_cls_out_auc: 0.5932 - val_cls_out_loss: 1.1131 - val_loc_out_loss: 0.0184 - val_loc_out_mae: 0.0513 - val_loss: 2.2844 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0072 - learning_rate: 5.0000e-05
# Epoch 2/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - cls_out_acc: 0.5331 - cls_out_auc: 0.5889 - cls_out_loss: 0.7724 - loc_out_loss: 0.0244 - loc_out_mae: 0.0853 - loss: 1.5636 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0067
# Epoch 2: val_cls_out_auc improved from 0.59315 to 0.61065, saving model to /content/best_fracturenet.keras
#
# Epoch 2: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 136s 760ms/step - cls_out_acc: 0.5357 - cls_out_auc: 0.5860 - cls_out_loss: 0.7770 - loc_out_loss: 0.0242 - loc_out_mae: 0.0827 - loss: 1.5646 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0069 - val_cls_out_acc: 0.6176 - val_cls_out_auc: 0.6107 - val_cls_out_loss: 0.7380 - val_loc_out_loss: 0.0173 - val_loc_out_mae: 0.0642 - val_loss: 1.5144 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0071 - learning_rate: 5.0000e-05
# Epoch 3/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - cls_out_acc: 0.5516 - cls_out_auc: 0.6149 - cls_out_loss: 0.6984 - loc_out_loss: 0.0201 - loc_out_mae: 0.0703 - loss: 1.4134 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0065
# Epoch 3: val_cls_out_auc did not improve from 0.61065
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 24s 136ms/step - cls_out_acc: 0.5374 - cls_out_auc: 0.5819 - cls_out_loss: 0.7616 - loc_out_loss: 0.0215 - loc_out_mae: 0.0726 - loss: 1.5364 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0067 - val_cls_out_acc: 0.6193 - val_cls_out_auc: 0.6093 - val_cls_out_loss: 0.7026 - val_loc_out_loss: 0.0171 - val_loc_out_mae: 0.0620 - val_loss: 1.4416 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0069 - learning_rate: 5.0000e-05
# Epoch 4/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - cls_out_acc: 0.5688 - cls_out_auc: 0.6366 - cls_out_loss: 0.6621 - loc_out_loss: 0.0195 - loc_out_mae: 0.0682 - loss: 1.3403 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0063
# Epoch 4: val_cls_out_auc improved from 0.61065 to 0.65370, saving model to /content/best_fracturenet.keras
#
# Epoch 4: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 119s 668ms/step - cls_out_acc: 0.5675 - cls_out_auc: 0.6322 - cls_out_loss: 0.7164 - loc_out_loss: 0.0209 - loc_out_mae: 0.0698 - loss: 1.4407 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0066 - val_cls_out_acc: 0.5931 - val_cls_out_auc: 0.6537 - val_cls_out_loss: 0.5629 - val_loc_out_loss: 0.0165 - val_loc_out_mae: 0.0593 - val_loss: 1.1553 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0067 - learning_rate: 5.0000e-05
# Epoch 5/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - cls_out_acc: 0.5483 - cls_out_auc: 0.6321 - cls_out_loss: 0.6978 - loc_out_loss: 0.0194 - loc_out_mae: 0.0651 - loss: 1.4115 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0063
# Epoch 5: val_cls_out_auc improved from 0.65370 to 0.69561, saving model to /content/best_fracturenet.keras
#
# Epoch 5: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 119s 666ms/step - cls_out_acc: 0.5574 - cls_out_auc: 0.6284 - cls_out_loss: 0.7404 - loc_out_loss: 0.0201 - loc_out_mae: 0.0657 - loss: 1.4965 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0066 - val_cls_out_acc: 0.6830 - val_cls_out_auc: 0.6956 - val_cls_out_loss: 0.5368 - val_loc_out_loss: 0.0163 - val_loc_out_mae: 0.0569 - val_loss: 1.1008 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0066 - learning_rate: 5.0000e-05
# Epoch 6/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - cls_out_acc: 0.5782 - cls_out_auc: 0.6364 - cls_out_loss: 0.6979 - loc_out_loss: 0.0184 - loc_out_mae: 0.0610 - loss: 1.4111 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0062
# Epoch 6: val_cls_out_auc improved from 0.69561 to 0.72930, saving model to /content/best_fracturenet.keras
#
# Epoch 6: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 115s 644ms/step - cls_out_acc: 0.5658 - cls_out_auc: 0.6301 - cls_out_loss: 0.7475 - loc_out_loss: 0.0196 - loc_out_mae: 0.0633 - loss: 1.5067 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0065 - val_cls_out_acc: 0.6977 - val_cls_out_auc: 0.7293 - val_cls_out_loss: 0.5468 - val_loc_out_loss: 0.0158 - val_loc_out_mae: 0.0562 - val_loss: 1.1215 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0065 - learning_rate: 5.0000e-05
# Epoch 7/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - cls_out_acc: 0.5558 - cls_out_auc: 0.6341 - cls_out_loss: 0.6308 - loc_out_loss: 0.0180 - loc_out_mae: 0.0592 - loss: 1.2768 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0062
# Epoch 7: val_cls_out_auc improved from 0.72930 to 0.74564, saving model to /content/best_fracturenet.keras
#
# Epoch 7: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 118s 664ms/step - cls_out_acc: 0.5626 - cls_out_auc: 0.6386 - cls_out_loss: 0.7279 - loc_out_loss: 0.0191 - loc_out_mae: 0.0608 - loss: 1.4673 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0064 - val_cls_out_acc: 0.7239 - val_cls_out_auc: 0.7456 - val_cls_out_loss: 0.5315 - val_loc_out_loss: 0.0160 - val_loc_out_mae: 0.0536 - val_loss: 1.0913 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0066 - learning_rate: 5.0000e-05
# Epoch 8/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - cls_out_acc: 0.6029 - cls_out_auc: 0.6705 - cls_out_loss: 0.6432 - loc_out_loss: 0.0172 - loc_out_mae: 0.0575 - loss: 1.3009 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0060
# Epoch 8: val_cls_out_auc improved from 0.74564 to 0.77946, saving model to /content/best_fracturenet.keras
#
# Epoch 8: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 126s 705ms/step - cls_out_acc: 0.6060 - cls_out_auc: 0.6713 - cls_out_loss: 0.7089 - loc_out_loss: 0.0186 - loc_out_mae: 0.0598 - loss: 1.4340 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.7288 - val_cls_out_auc: 0.7795 - val_cls_out_loss: 0.5320 - val_loc_out_loss: 0.0153 - val_loc_out_mae: 0.0547 - val_loss: 1.0927 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0065 - learning_rate: 5.0000e-05
# Epoch 9/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - cls_out_acc: 0.5983 - cls_out_auc: 0.6850 - cls_out_loss: 0.6159 - loc_out_loss: 0.0180 - loc_out_mae: 0.0596 - loss: 1.2468 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0060
# Epoch 9: val_cls_out_auc improved from 0.77946 to 0.78823, saving model to /content/best_fracturenet.keras
#
# Epoch 9: finished saving model to /content/best_fracturenet.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 119s 664ms/step - cls_out_acc: 0.6018 - cls_out_auc: 0.6804 - cls_out_loss: 0.6395 - loc_out_loss: 0.0190 - loc_out_mae: 0.0612 - loss: 1.2961 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.7761 - val_cls_out_auc: 0.7882 - val_cls_out_loss: 0.4959 - val_loc_out_loss: 0.0157 - val_loc_out_mae: 0.0524 - val_loss: 1.0207 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0064 - learning_rate: 5.0000e-05
# Epoch 10/10
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - cls_out_acc: 0.6041 - cls_out_auc: 0.6774 - cls_out_loss: 0.6129 - loc_out_loss: 0.0173 - loc_out_mae: 0.0562 - loss: 1.2404 - seg_out_acc: 0.9991 - seg_out_iou: 0.4996 - seg_out_loss: 0.0060
# Epoch 10: val_cls_out_auc did not improve from 0.78823
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 24s 130ms/step - cls_out_acc: 0.6088 - cls_out_auc: 0.6734 - cls_out_loss: 0.6516 - loc_out_loss: 0.0182 - loc_out_mae: 0.0578 - loss: 1.3177 - seg_out_acc: 0.9991 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063 - val_cls_out_acc: 0.7745 - val_cls_out_auc: 0.7781 - val_cls_out_loss: 0.5182 - val_loc_out_loss: 0.0155 - val_loc_out_mae: 0.0537 - val_loss: 1.0651 - val_seg_out_acc: 0.9990 - val_seg_out_iou: 0.4995 - val_seg_out_loss: 0.0063 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 9.
# 💾 Saved: /content/03_training_history.png
#
# ============================================================
# 📊 Test Set Evaluation
# ============================================================
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - cls_out_acc: 0.7716 - cls_out_auc: 0.7768 - cls_out_loss: 0.4520 - loc_out_loss: 0.0172 - loc_out_mae: 0.0538 - loss: 0.9300 - seg_out_acc: 0.9990 - seg_out_iou: 0.4995 - seg_out_loss: 0.0063
#
# 🎯 Test Metrics:
#   loss                               : 0.9300
#   compile_metrics                    : 0.4520
#   cls_out_loss                       : 0.0172
#   loc_out_loss                       : 0.0063
#   seg_out_loss                       : 0.7716
#
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
# Non-Fractured       0.89      0.82      0.86       506
#     Fractured       0.39      0.53      0.45       107
#
#      accuracy                           0.77       613
#     macro avg       0.64      0.68      0.65       613
#  weighted avg       0.80      0.77      0.78       613
#
# 🏆 AUC-ROC: 0.7772
# 💾 Saved: /content/04_confusion_matrix.png
# 💾 Saved: /content/05_predictions.png
#
# ╔══════════════════════════════════════════════════════════╗
# ║              ✅  TRAINING COMPLETE                        ║
# ╠══════════════════════════════════════════════════════════╣
# ║  Original dataset : 4083 images
# ║  Training dataset : 2858 samples (no oversampling)
# ║  Model            : FractureNet (EfficientNetB4)
# ║  Mixed Precision  : mixed_float16
# ║  Epochs run       : 20 (Phase1=10 + Phase2=10)
# ║  Best Val AUC     : 0.7882  (epoch 19)
# ║  Class Weights    : NonFrac=0.453 | Frac=2.422
# ║
# ║  📁 Outputs:
# ║    /content/best_fracturenet.keras
# ║    /content/01_data_analysis.png
# ║    /content/02_augmentation.png
# ║    /content/03_training_history.png
# ║    /content/04_confusion_matrix.png
# ║    /content/05_predictions.png
# ╚══════════════════════════════════════════════════════════╝
#
# ============================================================
# 🔍 Detailed Analysis: Confusion Matrix by Body Part
# ============================================================
#
# ==================== [HAND] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.80      0.71      0.75       136
#     Fractured       0.46      0.58      0.51        57
#
#      accuracy                           0.67       193
#     macro avg       0.63      0.65      0.63       193
#  weighted avg       0.70      0.67      0.68       193
#
#
# ==================== [HIP] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       1.00      0.92      0.96        26
#     Fractured       0.33      1.00      0.50         1
#
#      accuracy                           0.93        27
#     macro avg       0.67      0.96      0.73        27
#  weighted avg       0.98      0.93      0.94        27
#
#
# ==================== [LEG] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.94      0.87      0.90       287
#     Fractured       0.29      0.47      0.36        32
#
#      accuracy                           0.83       319
#     macro avg       0.62      0.67      0.63       319
#  weighted avg       0.87      0.83      0.85       319
#
#
# ==================== [MIXED] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       0.79      0.75      0.77        44
#     Fractured       0.39      0.44      0.41        16
#
#      accuracy                           0.67        60
#     macro avg       0.59      0.59      0.59        60
#  weighted avg       0.68      0.67      0.67        60
#
#
# ==================== [SHOULDER] ====================
#                precision    recall  f1-score   support
#
# Non-Fractured       1.00      0.85      0.92        13
#     Fractured       0.33      1.00      0.50         1
#
#      accuracy                           0.86        14
#     macro avg       0.67      0.92      0.71        14
#  weighted avg       0.95      0.86      0.89        14
# 💾 Saved: /content/06_cm_per_body_part.png
